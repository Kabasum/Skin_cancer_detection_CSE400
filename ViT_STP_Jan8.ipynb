# %%
import math
import numpy as np
import cv2
import os
import random
import tensorflow as tf
from tqdm import tqdm
from tensorflow import keras
import tensorflow_addons as tfa
import matplotlib.pyplot as plt
from tensorflow.keras import layers

# Setting seed for reproducibiltiy
SEED = 42
tf.random.set_seed(SEED)

# %%
DATADIR = r"C:\Users\sohan\Downloads\Training(Jan8)\Training"
CATEGORIES = ["bcc","nv"]
training_data = []
IMG_SIZE = 32
def create_training_data():
    for category in CATEGORIES:
        path = os.path.join(DATADIR,category)
        class_num = CATEGORIES.index(category)

        for img in tqdm(os.listdir(path)):
            try:
                img_array = cv2.imread(os.path.join(path,img))  # convert to array
                new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))  # resize to normalize data size
                training_data.append([new_array, class_num])  # add this to our training_data
            except Exception as e:  # in the interest in keeping the output clean...
                print(e)

create_training_data()

print(len(training_data))
# Out:
# 100%|██████████| 1260/1260 [00:19<00:00, 63.73it/s]
# 100%|██████████| 1260/1260 [00:13<00:00, 96.40it/s]
# 2520

# %%
random.shuffle(training_data)
X = []
y = []

for features,label in training_data:
    X.append(features)
    y.append(label)

print(X[0].reshape(-1, IMG_SIZE, IMG_SIZE, 3))

X = np.array(X).reshape(-1, IMG_SIZE, IMG_SIZE, 3)
# Out:
# [[[[124 132 161]
#    [127 140 172]
#    [123 139 175]
#    ...
#    [126 140 177]
#    [128 139 173]
#    [ 37  42  50]]
#
#   [[134 141 168]
#    [134 147 177]
#    [134 148 182]
#    ...
#    [124 143 178]
#    [129 143 176]
#    [117 130 162]]
#
#   [[127 141 170]
#    [137 150 180]
#    [136 151 183]
#    ...
#    [130 148 185]
#    [133 147 180]
#    [130 142 170]]
#
#   ...
#
#   [[124 137 171]
#    [125 143 179]
#    [128 141 179]
#    ...
#    [126 142 181]
#    [120 136 173]
#    [112 123 159]]
#
#   [[127 138 168]
#    [134 147 178]
#    [128 141 178]
#    ...
#    [133 143 175]
#    [136 145 173]
#    [ 30  31  35]]
#
#   [[ 89 109 147]
#    [105 124 157]
#    [118 134 167]
#    ...
#    [129 141 171]
#    [127 138 166]
#    [ 60  62  66]]]]

# %%
from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val = train_test_split(X, y, test_size=0.30, random_state=42)
x_val, x_test, y_val, y_test = train_test_split(x_val, y_val, test_size=0.33, random_state=42)

# %%
y_train=np.array(y_train)
y_val=np.array(y_val)
y_test=np.array(y_test)
print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_train shape: {x_val.shape} - y_train shape: {y_val.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
# Out:
# x_train shape: (1764, 32, 32, 3) - y_train shape: (1764,)
# x_train shape: (506, 32, 32, 3) - y_train shape: (506,)
# x_test shape: (250, 32, 32, 3) - y_test shape: (250,)

# %%
NUM_CLASSES = 2
INPUT_SHAPE = (32, 32, 3)

# %%
# DATA
BUFFER_SIZE = 512
BATCH_SIZE = 128


# AUGMENTATION
IMAGE_SIZE = 72
PATCH_SIZE = 6
NUM_PATCHES = (IMAGE_SIZE // PATCH_SIZE) ** 2

# OPTIMIZER
LEARNING_RATE = 0.001
WEIGHT_DECAY = 0.0001

# TRAINING
EPOCHS = 100

# ARCHITECTURE
LAYER_NORM_EPS = 1e-6
TRANSFORMER_LAYERS = 8
PROJECTION_DIM = 64
NUM_HEADS = 4
TRANSFORMER_UNITS = [
    PROJECTION_DIM * 2,
    PROJECTION_DIM,
]
MLP_HEAD_UNITS = [2048, 1024]

# %%
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(IMAGE_SIZE, IMAGE_SIZE),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(height_factor=0.2, width_factor=0.2),
    ],
    name="data_augmentation",
)
# Compute the mean and the variance of the training data for normalization.
data_augmentation.layers[0].adapt(x_train)

# %%
class ShiftedPatchTokenization(layers.Layer):
    def __init__(
        self,
        image_size=IMAGE_SIZE,
        patch_size=PATCH_SIZE,
        num_patches=NUM_PATCHES,
        projection_dim=PROJECTION_DIM,
        vanilla=False,
        **kwargs,
    ):
        super().__init__(**kwargs)
        self.vanilla = vanilla  # Flag to swtich to vanilla patch extractor
        self.image_size = image_size
        self.patch_size = patch_size
        self.half_patch = patch_size // 2
        self.flatten_patches = layers.Reshape((num_patches, -1))
        self.projection = layers.Dense(units=projection_dim)
        self.layer_norm = layers.LayerNormalization(epsilon=LAYER_NORM_EPS)

    def crop_shift_pad(self, images, mode):
        # Build the diagonally shifted images
        if mode == "left-up":
            crop_height = self.half_patch
            crop_width = self.half_patch
            shift_height = 0
            shift_width = 0
        elif mode == "left-down":
            crop_height = 0
            crop_width = self.half_patch
            shift_height = self.half_patch
            shift_width = 0
        elif mode == "right-up":
            crop_height = self.half_patch
            crop_width = 0
            shift_height = 0
            shift_width = self.half_patch
        else:
            crop_height = 0
            crop_width = 0
            shift_height = self.half_patch
            shift_width = self.half_patch

        # Crop the shifted images and pad them
        crop = tf.image.crop_to_bounding_box(
            images,
            offset_height=crop_height,
            offset_width=crop_width,
            target_height=self.image_size - self.half_patch,
            target_width=self.image_size - self.half_patch,
        )
        shift_pad = tf.image.pad_to_bounding_box(
            crop,
            offset_height=shift_height,
            offset_width=shift_width,
            target_height=self.image_size,
            target_width=self.image_size,
        )
        return shift_pad

    def call(self, images):
        if not self.vanilla:
            # Concat the shifted images with the original image
            images = tf.concat(
                [
                    images,
                    self.crop_shift_pad(images, mode="left-up"),
                    self.crop_shift_pad(images, mode="left-down"),
                    self.crop_shift_pad(images, mode="right-up"),
                    self.crop_shift_pad(images, mode="right-down"),
                ],
                axis=-1,
            )
        # Patchify the images and flatten it
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        flat_patches = self.flatten_patches(patches)
        if not self.vanilla:
            # Layer normalize the flat patches and linearly project it
            tokens = self.layer_norm(flat_patches)
            tokens = self.projection(tokens)
        else:
            # Linearly project the flat patches
            tokens = self.projection(flat_patches)
        return (tokens, patches)

# %%
# Get a random image from the training dataset
# and resize the image
image = x_train[np.random.choice(range(x_train.shape[0]))]
resized_image = tf.image.resize(
    tf.convert_to_tensor([image]), size=(IMAGE_SIZE, IMAGE_SIZE)
)

# Vanilla patch maker: This takes an image and divides into
# patches as in the original ViT paper
(token, patch) = ShiftedPatchTokenization(vanilla=True)(resized_image / 255.0)
(token, patch) = (token[0], patch[0])
n = patch.shape[0]
count = 1
plt.figure(figsize=(4, 4))
for row in range(n):
    for col in range(n):
        plt.subplot(n, n, count)
        count = count + 1
        image = tf.reshape(patch[row][col], (PATCH_SIZE, PATCH_SIZE, 3))
        plt.imshow(image)
        plt.axis("off")
plt.show()

# Shifted Patch Tokenization: This layer takes the image, shifts it
# diagonally and then extracts patches from the concatinated images
(token, patch) = ShiftedPatchTokenization(vanilla=False)(resized_image / 255.0)
(token, patch) = (token[0], patch[0])
n = patch.shape[0]
shifted_images = ["ORIGINAL", "LEFT-UP", "LEFT-DOWN", "RIGHT-UP", "RIGHT-DOWN"]
for index, name in enumerate(shifted_images):
    print(name)
    count = 1
    plt.figure(figsize=(4, 4))
    for row in range(n):
        for col in range(n):
            plt.subplot(n, n, count)
            count = count + 1
            image = tf.reshape(patch[row][col], (PATCH_SIZE, PATCH_SIZE, 5 * 3))
            plt.imshow(image[..., 3 * index : 3 * index + 3])
            plt.axis("off")
    plt.show()
# Out:
# ORIGINAL
# LEFT-UP
# LEFT-DOWN
# RIGHT-UP
# RIGHT-DOWN

# %%
class PatchEncoder(layers.Layer):
    def __init__(
        self, num_patches=NUM_PATCHES, projection_dim=PROJECTION_DIM, **kwargs
    ):
        super().__init__(**kwargs)
        self.num_patches = num_patches
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )
        self.positions = tf.range(start=0, limit=self.num_patches, delta=1)

    def call(self, encoded_patches):
        encoded_positions = self.position_embedding(self.positions)
        encoded_patches = encoded_patches + encoded_positions
        return encoded_patches

# %%
class MultiHeadAttentionLSA(tf.keras.layers.MultiHeadAttention):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        # The trainable temperature term. The initial value is
        # the square root of the key dimension.
        self.tau = tf.Variable(math.sqrt(float(self._key_dim)), trainable=True)

    def _compute_attention(self, query, key, value, attention_mask=None, training=None):
        query = tf.multiply(query, 1.0 / self.tau)
        attention_scores = tf.einsum(self._dot_product_equation, key, query)
        attention_scores = self._masked_softmax(attention_scores, attention_mask)
        attention_scores_dropout = self._dropout_layer(
            attention_scores, training=training
        )
        attention_output = tf.einsum(
            self._combine_equation, attention_scores_dropout, value
        )
        return attention_output, attention_scores

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x


# Build the diagonal attention mask
diag_attn_mask = 1 - tf.eye(NUM_PATCHES)
diag_attn_mask = tf.cast([diag_attn_mask], dtype=tf.int8)

# %%
def create_vit_classifier(vanilla=False):
    inputs = layers.Input(shape=INPUT_SHAPE)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    (tokens, _) = ShiftedPatchTokenization(vanilla=vanilla)(augmented)
    # Encode patches.
    encoded_patches = PatchEncoder()(tokens)

    # Create multiple layers of the Transformer block.
    for _ in range(TRANSFORMER_LAYERS):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        if not vanilla:
            attention_output = MultiHeadAttentionLSA(
                num_heads=NUM_HEADS, key_dim=PROJECTION_DIM, dropout=0.1
            )(x1, x1, attention_mask=diag_attn_mask)
        else:
            attention_output = layers.MultiHeadAttention(
                num_heads=NUM_HEADS, key_dim=PROJECTION_DIM, dropout=0.1
            )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=TRANSFORMER_UNITS, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=MLP_HEAD_UNITS, dropout_rate=0.5)
    # Classify outputs.
    logits = layers.Dense(NUM_CLASSES)(features)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model

# %%
class WarmUpCosine(keras.optimizers.schedules.LearningRateSchedule):
    def __init__(
        self, learning_rate_base, total_steps, warmup_learning_rate, warmup_steps
    ):
        super().__init__()

        self.learning_rate_base = learning_rate_base
        self.total_steps = total_steps
        self.warmup_learning_rate = warmup_learning_rate
        self.warmup_steps = warmup_steps
        self.pi = tf.constant(np.pi)

    def __call__(self, step):
        if self.total_steps < self.warmup_steps:
            raise ValueError("Total_steps must be larger or equal to warmup_steps.")

        cos_annealed_lr = tf.cos(
            self.pi
            * (tf.cast(step, tf.float32) - self.warmup_steps)
            / float(self.total_steps - self.warmup_steps)
        )
        learning_rate = 0.5 * self.learning_rate_base * (1 + cos_annealed_lr)

        if self.warmup_steps > 0:
            if self.learning_rate_base < self.warmup_learning_rate:
                raise ValueError(
                    "Learning_rate_base must be larger or equal to "
                    "warmup_learning_rate."
                )
            slope = (
                self.learning_rate_base - self.warmup_learning_rate
            ) / self.warmup_steps
            warmup_rate = slope * tf.cast(step, tf.float32) + self.warmup_learning_rate
            learning_rate = tf.where(
                step < self.warmup_steps, warmup_rate, learning_rate
            )
        return tf.where(
            step > self.total_steps, 0.0, learning_rate, name="learning_rate"
        )

# %%
def run_experiment(model):
    total_steps = int((len(x_train) / BATCH_SIZE) * EPOCHS)
    warmup_epoch_percentage = 0.10
    warmup_steps = int(total_steps * warmup_epoch_percentage)
    scheduled_lrs = WarmUpCosine(
        learning_rate_base=LEARNING_RATE,
        total_steps=total_steps,
        warmup_learning_rate=0.0,
        warmup_steps=warmup_steps,
    )

    optimizer = tfa.optimizers.AdamW(
        learning_rate=LEARNING_RATE, weight_decay=WEIGHT_DECAY
    )

    model.compile(
        optimizer=optimizer,
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            keras.metrics.SparseTopKCategoricalAccuracy(4, name="top-4-accuracy"),
        ],
    )

    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=BATCH_SIZE,
        epochs=EPOCHS,
        validation_split=0.1,
    )
    _, accuracy, top_4_accuracy = model.evaluate(x_test, y_test, batch_size=BATCH_SIZE)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 4 accuracy: {round(top_4_accuracy * 100, 2)}%")

    return history


# Run experiments with the vanilla ViT
vit = create_vit_classifier(vanilla=True)
history = run_experiment(vit)

# Run experiments with the Shifted Patch Tokenization and
# Locality Self Attention modified ViT
vit_sl = create_vit_classifier(vanilla=False)
history = run_experiment(vit_sl)
# Out:
# Epoch 1/100
# 13/13 [==============================] - 11s 234ms/step - loss: 4.4683 - accuracy: 0.6723 - top-4-accuracy: 1.0000 - val_loss: 2.1301 - val_accuracy: 0.7401 - val_top-4-accuracy: 1.0000
# Epoch 2/100
# 13/13 [==============================] - 2s 159ms/step - loss: 1.5219 - accuracy: 0.6868 - top-4-accuracy: 1.0000 - val_loss: 0.4692 - val_accuracy: 0.7627 - val_top-4-accuracy: 1.0000
# Epoch 3/100
# 13/13 [==============================] - 2s 162ms/step - loss: 0.6944 - accuracy: 0.7360 - top-4-accuracy: 1.0000 - val_loss: 0.4136 - val_accuracy: 0.8023 - val_top-4-accuracy: 1.0000
# Epoch 4/100
# 13/13 [==============================] - 2s 159ms/step - loss: 0.5337 - accuracy: 0.7738 - top-4-accuracy: 1.0000 - val_loss: 0.4208 - val_accuracy: 0.7740 - val_top-4-accuracy: 1.0000
# Epoch 5/100
# 13/13 [==============================] - 2s 160ms/step - loss: 0.4744 - accuracy: 0.7996 - top-4-accuracy: 1.0000 - val_loss: 0.3083 - val_accuracy: 0.8757 - val_top-4-accuracy: 1.0000
# Epoch 6/100
# 13/13 [==============================] - 2s 158ms/step - loss: 0.4001 - accuracy: 0.8147 - top-4-accuracy: 1.0000 - val_loss: 0.2679 - val_accuracy: 0.8814 - val_top-4-accuracy: 1.0000
# Epoch 7/100
# 13/13 [==============================] - 2s 161ms/step - loss: 0.3794 - accuracy: 0.8399 - top-4-accuracy: 1.0000 - val_loss: 0.2381 - val_accuracy: 0.8983 - val_top-4-accuracy: 1.0000
# Epoch 8/100
# 13/13 [==============================] - 2s 158ms/step - loss: 0.3551 - accuracy: 0.8494 - top-4-accuracy: 1.0000 - val_loss: 0.2262 - val_accuracy: 0.9435 - val_top-4-accuracy: 1.0000
# Epoch 9/100
# 13/13 [==============================] - 2s 158ms/step - loss: 0.2866 - accuracy: 0.8778 - top-4-accuracy: 1.0000 - val_loss: 0.1722 - val_accuracy: 0.9266 - val_top-4-accuracy: 1.0000
# Epoch 10/100
# 13/13 [==============================] - 2s 160ms/step - loss: 0.2858 - accuracy: 0.8784 - top-4-accuracy: 1.0000 - val_loss: 0.2071 - val_accuracy: 0.9040 - val_top-4-accuracy: 1.0000
# Epoch 11/100
# 13/13 [==============================] - 2s 159ms/step - loss: 0.2383 - accuracy: 0.8948 - top-4-accuracy: 1.0000 - val_loss: 0.1275 - val_accuracy: 0.9605 - val_top-4-accuracy: 1.0000
# Epoch 12/100
# 13/13 [==============================] - 2s 159ms/step - loss: 0.2377 - accuracy: 0.8998 - top-4-accuracy: 1.0000 - val_loss: 0.1384 - val_accuracy: 0.9379 - val_top-4-accuracy: 1.0000
# Epoch 13/100
# 13/13 [==============================] - 2s 158ms/step - loss: 0.2105 - accuracy: 0.9212 - top-4-accuracy: 1.0000 - val_loss: 0.1030 - val_accuracy: 0.9661 - val_top-4-accuracy: 1.0000
# Epoch 14/100
# 13/13 [==============================] - 2s 160ms/step - loss: 0.1860 - accuracy: 0.9301 - top-4-accuracy: 1.0000 - val_loss: 0.1027 - val_accuracy: 0.9605 - val_top-4-accuracy: 1.0000
# Epoch 15/100
# 13/13 [==============================] - 2s 158ms/step - loss: 0.1619 - accuracy: 0.9326 - top-4-accuracy: 1.0000 - val_loss: 0.0837 - val_accuracy: 0.9605 - val_top-4-accuracy: 1.0000
# Epoch 16/100
# 13/13 [==============================] - 2s 158ms/step - loss: 0.1727 - accuracy: 0.9382 - top-4-accuracy: 1.0000 - val_loss: 0.0860 - val_accuracy: 0.9718 - val_top-4-accuracy: 1.0000
# Epoch 17/100
# 13/13 [==============================] - 2s 159ms/step - loss: 0.1764 - accuracy: 0.9351 - top-4-accuracy: 1.0000 - val_loss: 0.0924 - val_accuracy: 0.9605 - val_top-4-accuracy: 1.0000
# Epoch 18/100
# 13/13 [==============================] - 2s 161ms/step - loss: 0.1483 - accuracy: 0.9458 - top-4-accuracy: 1.0000 - val_loss: 0.0853 - val_accuracy: 0.9718 - val_top-4-accuracy: 1.0000
# Epoch 19/100
# 13/13 [==============================] - 2s 160ms/step - loss: 0.1359 - accuracy: 0.9483 - top-4-accuracy: 1.0000 - val_loss: 0.0630 - val_accuracy: 0.9831 - val_top-4-accuracy: 1.0000
# Epoch 20/100
# 13/13 [==============================] - 2s 160ms/step - loss: 0.1376 - accuracy: 0.9464 - top-4-accuracy: 1.0000 - val_loss: 0.0506 - val_accuracy: 0.9887 - val_top-4-accuracy: 1.0000
# Epoch 21/100
# 13/13 [==============================] - 2s 161ms/step - loss: 0.1362 - accuracy: 0.9527 - top-4-accuracy: 1.0000 - val_loss: 0.0570 - val_accuracy: 0.9944 - val_top-4-accuracy: 1.0000
# Epoch 22/100
# 13/13 [==============================] - 2s 160ms/step - loss: 0.1073 - accuracy: 0.9578 - top-4-accuracy: 1.0000 - val_loss: 0.0633 - val_accuracy: 0.9831 - val_top-4-accuracy: 1.0000
# Epoch 23/100
# 13/13 [==============================] - 2s 159ms/step - loss: 0.1280 - accuracy: 0.9565 - top-4-accuracy: 1.0000 - val_loss: 0.0523 - val_accuracy: 0.9774 - val_top-4-accuracy: 1.0000
# Epoch 24/100
# 13/13 [==============================] - 2s 160ms/step - loss: 0.1089 - accuracy: 0.9603 - top-4-accuracy: 1.0000 - val_loss: 0.0482 - val_accuracy: 0.9831 - val_top-4-accuracy: 1.0000
# Epoch 25/100
# 13/13 [==============================] - 2s 160ms/step - loss: 0.1030 - accuracy: 0.9622 - top-4-accuracy: 1.0000 - val_loss: 0.0472 - val_accuracy: 0.9887 - val_top-4-accuracy: 1.0000
# Epoch 26/100
# 13/13 [==============================] - 2s 162ms/step - loss: 0.0967 - accuracy: 0.9572 - top-4-accuracy: 1.0000 - val_loss: 0.0465 - val_accuracy: 0.9887 - val_top-4-accuracy: 1.0000
# Epoch 27/100
# 13/13 [==============================] - 2s 158ms/step - loss: 0.0851 - accuracy: 0.9666 - top-4-accuracy: 1.0000 - val_loss: 0.0390 - val_accuracy: 0.9887 - val_top-4-accuracy: 1.0000
# Epoch 28/100
# 13/13 [==============================] - 2s 159ms/step - loss: 0.0857 - accuracy: 0.9666 - top-4-accuracy: 1.0000 - val_loss: 0.0360 - val_accuracy: 0.9887 - val_top-4-accuracy: 1.0000
# Epoch 29/100
# 13/13 [==============================] - 2s 159ms/step - loss: 0.0855 - accuracy: 0.9748 - top-4-accuracy: 1.0000 - val_loss: 0.0441 - val_accuracy: 0.9831 - val_top-4-accuracy: 1.0000
# Epoch 30/100
# 13/13 [==============================] - 2s 159ms/step - loss: 0.0747 - accuracy: 0.9691 - top-4-accuracy: 1.0000 - val_loss: 0.0627 - val_accuracy: 0.9718 - val_top-4-accuracy: 1.0000
# Epoch
100
# 13/13 [==============================] - 2s 162ms/step - loss: 0.0401 - accuracy: 0.9849 - top-4-accuracy: 1.0000 - val_loss: 0.0569 - val_accuracy: 0.9774 - val_top-4-accuracy: 1.0000
# Epoch 73/100
# 13/13 [==============================] - 2s 159ms/step - loss: 0.0170 - accuracy: 0.9950 - top-4-accuracy: 1.0000 - val_loss: 0.0423 - val_accuracy: 0.9831 - val_top-4-accuracy: 1.0000
# Epoch 74/100
# 13/13 [==============================] - 2s 159ms/step - loss: 0.0123 - accuracy: 0.9937 - top-4-accuracy: 1.0000 - val_loss: 0.0719 - val_accuracy: 0.9831 - val_top-4-accuracy: 1.0000
# Epoch 75/100
# 13/13 [==============================] - 2s 159ms/step - loss: 0.0139 - accuracy: 0.9956 - top-4-accuracy: 1.0000 - val_loss: 0.0775 - val_accuracy: 0.9831 - val_top-4-accuracy: 1.0000
# Epoch 76/100
# 13/13 [==============================] - 2s 160ms/step - loss: 0.0350 - accuracy: 0.9887 - top-4-accuracy: 1.0000 - val_loss: 0.0079 - val_accuracy: 1.0000 - val_top-4-accuracy: 1.0000
# Epoch 77/100
# 13/13 [==============================] - 2s 158ms/step - loss: 0.0120 - accuracy: 0.9931 - top-4-accuracy: 1.0000 - val_loss: 0.0456 - val_accuracy: 0.9887 - val_top-4-accuracy: 1.0000
# Epoch 78/100
# 13/13 [==============================] - 2s 158ms/step - loss: 0.0141 - accuracy: 0.9950 - top-4-accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000 - val_top-4-accuracy: 1.0000
# Epoch 79/100
# 13/13 [==============================] - 2s 159ms/step - loss: 0.0237 - accuracy: 0.9931 - top-4-accuracy: 1.0000 - val_loss: 0.0684 - val_accuracy: 0.9831 - val_top-4-accuracy: 1.0000
# Epoch 80/100
# 13/13 [==============================] - 2s 162ms/step - loss: 0.0381 - accuracy: 0.9868 - top-4-accuracy: 1.0000 - val_loss: 0.0761 - val_accuracy: 0.9774 - val_top-4-accuracy: 1.0000
# Epoch 81/100
# 13/13 [==============================] - 2s 157ms/step - loss: 0.0246 - accuracy: 0.9918 - top-4-accuracy: 1.0000 - val_loss: 0.0393 - val_accuracy: 0.9887 - val_top-4-accuracy: 1.0000
# Epoch 82/100
# 13/13 [==============================] - 2s 157ms/step - loss: 0.0258 - accuracy: 0.9887 - top-4-accuracy: 1.0000 - val_loss: 0.0391 - val_accuracy: 0.9887 - val_top-4-accuracy: 1.0000
# Epoch 83/100
# 13/13 [==============================] - 2s 157ms/step - loss: 0.0262 - accuracy: 0.9918 - top-4-accuracy: 1.0000 - val_loss: 0.0357 - val_accuracy: 0.9831 - val_top-4-accuracy: 1.0000
# Epoch 84/100
# 13/13 [==============================] - 2s 158ms/step - loss: 0.0345 - accuracy: 0.9905 - top-4-accuracy: 1.0000 - val_loss: 0.1042 - val_accuracy: 0.9605 - val_top-4-accuracy: 1.0000
# Epoch 85/100
# 13/13 [==============================] - 2s 157ms/step - loss: 0.0301 - accuracy: 0.9905 - top-4-accuracy: 1.0000 - val_loss: 0.0223 - val_accuracy: 0.9887 - val_top-4-accuracy: 1.0000
# Epoch 86/100
# 13/13 [==============================] - 2s 158ms/step - loss: 0.0536 - accuracy: 0.9849 - top-4-accuracy: 1.0000 - val_loss: 0.0849 - val_accuracy: 0.9718 - val_top-4-accuracy: 1.0000
# Epoch 87/100
# 13/13 [==============================] - 2s 160ms/step - loss: 0.0578 - accuracy: 0.9786 - top-4-accuracy: 1.0000 - val_loss: 0.0691 - val_accuracy: 0.9887 - val_top-4-accuracy: 1.0000
# Epoch 88/100
# 13/13 [==============================] - 2s 162ms/step - loss: 0.0362 - accuracy: 0.9880 - top-4-accuracy: 1.0000 - val_loss: 0.0799 - val_accuracy: 0.9661 - val_top-4-accuracy: 1.0000
# Epoch 89/100
# 13/13 [==============================] - 2s 162ms/step - loss: 0.0255 - accuracy: 0.9887 - top-4-accuracy: 1.0000 - val_loss: 0.0206 - val_accuracy: 0.9944 - val_top-4-accuracy: 1.0000
# Epoch 90/100
# 13/13 [==============================] - 2s 160ms/step - loss: 0.0254 - accuracy: 0.9918 - top-4-accuracy: 1.0000 - val_loss: 0.0664 - val_accuracy: 0.9887 - val_top-4-accuracy: 1.0000
# Epoch 91/100
# 13/13 [==============================] - 2s 161ms/step - loss: 0.0251 - accuracy: 0.9899 - top-4-accuracy: 1.0000 - val_loss: 0.0249 - val_accuracy: 0.9944 - val_top-4-accuracy: 1.0000
# Epoch 92/100
# 13/13 [==============================] - 2s 163ms/step - loss: 0.0217 - accuracy: 0.9924 - top-4-accuracy: 1.0000 - val_loss: 0.0052 - val_accuracy: 1.0000 - val_top-4-accuracy: 1.0000
# Epoch 93/100
# 13/13 [==============================] - 2s 161ms/step - loss: 0.0152 - accuracy: 0.9943 - top-4-accuracy: 1.0000 - val_loss: 0.0727 - val_accuracy: 0.9887 - val_top-4-accuracy: 1.0000
# Epoch 94/100
# 13/13 [==============================] - 2s 161ms/step - loss: 0.0154 - accuracy: 0.9950 - top-4-accuracy: 1.0000 - val_loss: 0.0173 - val_accuracy: 0.9887 - val_top-4-accuracy: 1.0000
# Epoch 95/100
# 13/13 [==============================] - 2s 162ms/step - loss: 0.0172 - accuracy: 0.9931 - top-4-accuracy: 1.0000 - val_loss: 0.0381 - val_accuracy: 0.9831 - val_top-4-accuracy: 1.0000
# Epoch 96/100
# 13/13 [==============================] - 2s 158ms/step - loss: 0.0475 - accuracy: 0.9868 - top-4-accuracy: 1.0000 - val_loss: 0.0758 - val_accuracy: 0.9774 - val_top-4-accuracy: 1.0000
# Epoch 97/100
# 13/13 [==============================] - 2s 159ms/step - loss: 0.0258 - accuracy: 0.9905 - top-4-accuracy: 1.0000 - val_loss: 0.0319 - val_accuracy: 0.9887 - val_top-4-accuracy: 1.0000
# Epoch 98/100
# 13/13 [==============================] - 2s 158ms/step - loss: 0.0201 - accuracy: 0.9937 - top-4-accuracy: 1.0000 - val_loss: 0.0607 - val_accuracy: 0.9831 - val_top-4-accuracy: 1.0000
# Epoch 99/100
# 13/13 [==============================] - 2s 160ms/step - loss: 0.0099 - accuracy: 0.9968 - top-4-accuracy: 1.0000 - val_loss: 0.0616 - val_accuracy: 0.9831 - val_top-4-accuracy: 1.0000
# Epoch 100/100
# 13/13 [==============================] - 2s 158ms/step - loss: 0.0072 - accuracy: 0.9968 - top-4-accuracy: 1.0000 - val_loss: 0.0769 - val_accuracy: 0.9831 - val_top-4-accuracy: 1.0000
# 2/2 [==============================] - 0s 38ms/step - loss: 0.2341 - accuracy: 0.9680 - top-4-accuracy: 1.0000
# Test accuracy: 96.8%
# Test top 4 accuracy: 100.0%
# Epoch 1/100
# 13/13 [==============================] - 12s 252ms/step - loss: 2.8633 - accuracy: 0.6566 - top-4-accuracy: 1.0000 - val_loss: 0.5086 - val_accuracy: 0.8362 - val_top-4-accuracy: 1.0000
# Epoch 2/100
# 13/13 [==============================] - 2s 171ms/step - loss: 1.0848 - accuracy: 0.7656 - top-4-accuracy: 1.0000 - val_loss: 0.3752 - val_accuracy: 0.8305 - val_top-4-accuracy: 1.0000
# Epoch 3/100
# 13/13 [==============================] - 2s 167ms/step - loss: 0.6081 - accuracy: 0.8066 - top-4-accuracy: 1.0000 - val_loss: 0.2131 - val_accuracy: 0.9096 - val_top-4-accuracy: 1.0000
# Epoch 4/100
# 13/13 [==============================] - 2s 170ms/step - loss: 0.4577 - accuracy: 0.8336 - top-4-accuracy: 1.0000 - val_loss: 0.2167 - val_accuracy: 0.9040 - val_top-4-accuracy: 1.0000
# Epoch 5/100
# 13/13 [==============================] - 2s 180ms/step - loss: 0.4128 - accuracy: 0.8343 - top-4-accuracy: 1.0000 - val_loss: 0.1853 - val_accuracy: 0.9322 - val_top-4-accuracy: 1.0000
# Epoch 6/100
# 13/13 [==============================] - 2s 175ms/step - loss: 0.3465 - accuracy: 0.8595 - top-4-accuracy: 1.0000 - val_loss: 0.1808 - val_accuracy: 0.9379 - val_top-4-accuracy: 1.0000
# Epoch 7/100
# 13/13 [==============================] - 2s 177ms/step - loss: 0.3234 - accuracy: 0.8727 - top-4-accuracy: 1.0000 - val_loss: 0.1694 - val_accuracy: 0.9548 - val_top-4-accuracy: 1.0000
# Epoch 8/100
# 13/13 [==============================] - 2s 176ms/step - loss: 0.2660 - accuracy: 0.8929 - top-4-accuracy: 1.0000 - val_loss: 0.1513 - val_accuracy: 0.9435 - val_top-4-accuracy: 1.0000
# Epoch 9/100
# 13/13 [==============================] - 2s 177ms/step - loss: 0.2564 - accuracy: 0.8973 - top-4-accuracy: 1.0000 - val_loss: 0.1797 - val_accuracy: 0.9209 - val_top-4-accuracy: 1.0000
# Epoch 10/100
# 13/13 [==============================] - 2s 172ms/step - loss: 0.2184 - accuracy: 0.9017 - top-4-accuracy: 1.0000 - val_loss: 0.1525 - val_accuracy: 0.9492 - val_top-4-accuracy: 1.0000
# Epoch 11/100
# 13/13 [==============================] - 2s 171ms/step - loss: 0.2012 - accuracy: 0.9206 - top-4-accuracy: 1.0000 - val_loss: 0.1466 - val_accuracy: 0.9548 - val_top-4-accuracy: 1.0000
# Epoch 12/100
# 13/13 [==============================] - 2s 171ms/step - loss: 0.1821 - accuracy: 0.9301 - top-4-accuracy: 1.0000 - val_loss: 0.1256 - val_accuracy: 0.9548 - val_top-4-accuracy: 1.0000
# Epoch 13/100
# 13/13 [==============================] - 2s 169ms/step - loss: 0.1874 - accuracy: 0.9269 - top-4-accuracy: 1.0000 - val_loss: 0.1228 - val_accuracy: 0.9605 - val_top-4-accuracy: 1.0000
# Epoch 14/100
# 13/13 [==============================] - 2s 170ms/step - loss: 0.1823 - accuracy: 0.9269 - top-4-accuracy: 1.0000 - val_loss: 0.1363 - val_accuracy: 0.9435 - val_top-4-accuracy: 1.0000
# Epoch 15/100
# 13/13 [==============================] - 2s 169ms/step - loss: 0.1774 - accuracy: 0.9338 - top-4-accuracy: 1.0000 - val_loss: 0.1346 - val_accuracy: 0.9605 - val_top-4-accuracy: 1.0000
# Epoch 16/100
# 13/13 [==============================] - 2s 169ms/step - loss: 0.1367 - accuracy: 0.9439 - top-4-accuracy: 1.0000 - val_loss: 0.0860 - val_accuracy: 0.9887 - val_top-4-accuracy: 1.0000
# Epoch 17/100
# 13/13 [==============================] - 2s 169ms/step - loss: 0.1674 - accuracy: 0.9282 - top-4-accuracy: 1.0000 - val_loss: 0.1584 - val_accuracy: 0.9322 - val_top-4-accuracy: 1.0000
# Epoch 18/100
# 13/13 [==============================] - 2s 168ms/step - loss: 0.1306 - accuracy: 0.9534 - top-4-accuracy: 1.0000 - val_loss: 0.0651 - val_accuracy: 0.9718 - val_top-4-accuracy: 1.0000
# Epoch 19/100
# 13/13 [==============================] - 2s 170ms/step - loss: 0.1167 - accuracy: 0.9546 - top-4-accuracy: 1.0000 - val_loss: 0.0727 - val_accuracy: 0.9718 - val_top-4-accuracy: 1.0000
# Epoch 20/100
# 13/13 [==============================] - 2s 169ms/step - loss: 0.1089 - accuracy: 0.9527 - top-4-accuracy: 1.0000 - val_loss: 0.0927 - val_accuracy: 0.9661 - val_top-4-accuracy: 1.0000
# Epoch 21/100
# 13/13 [==============================] - 2s 168ms/step - loss: 0.1526 - accuracy: 0.9433 - top-4-accuracy: 1.0000 - val_loss: 0.0712 - val_accuracy: 0.9887 - val_top-4-accuracy: 1.0000
# Epoch 22/100
# 13/13 [==============================] - 2s 168ms/step - loss: 0.1377 - accuracy: 0.9572 - top-4-accuracy: 1.0000 - val_loss: 0.0913 - val_accuracy: 0.9887 - val_top-4-accuracy: 1.0000
# Epoch 23/100
# 13/13 [==============================] - 2s 168ms/step - loss: 0.1060 - accuracy: 0.9565 - top-4-accuracy: 1.0000 - val_loss: 0.1185 - val_accuracy: 0.9831 - val_top-4-accuracy: 1.0000
# Epoch 24/100
# 13/13 [==============================] - 2s 168ms/step - loss: 0.0893 - accuracy: 0.9647 - top-4-accuracy: 1.0000 - val_loss: 0.1095 - val_accuracy: 0.9718 - val_top-4-accuracy: 1.0000
# Epoch 25/100
# 13/13 [==============================] - 2s 168ms/step - loss: 0.1104 - accuracy: 0.9584 - top-4-accuracy: 1.0000 - val_loss: 0.0781 - val_accuracy: 0.9718 - val_top-4-accuracy: 1.0000
# Epoch 26/100
# 13/13 [==============================] - 2s 169ms/step - loss: 0.0963 - accuracy: 0.9679 - top-4-accuracy: 1.0000 - val_loss: 0.0986 - val_accuracy: 0.9831 - val_top-4-accuracy: 1.0000
# Epoch 27/100
# 13/13 [==============================] - 2s 168ms/step - loss: 0.0846 - accuracy: 0.9679 - top-4-accuracy: 1.0000 - val_loss: 0.0969 - val_accuracy: 0.9774 - val_top-4-accuracy: 1.0000
# Epoch 28/100
# 13/13 [==============================] - 2s 170ms/step - loss: 0.0750 - accuracy: 0.9723 - top-4-accuracy: 1.0000 - val_loss: 0.1769 - val_accuracy: 0.9605 - val_top-4-accuracy: 1.0000
# Epoch 29/100
# 13/13 [==============================] - 2s 173ms/step - loss: 0.0934 - accuracy: 0.9622 - top-4-accuracy: 1.0000 - val_loss: 0.1175 - val_accuracy: 0.9661 - val_top-4-accuracy: 1.0000
# Epoch 30/100
# 13/13 [==============================] - 2s 174ms/step - loss: 0.0750 - accuracy: 0.9716 - top-4-accuracy: 1.0000 - val_loss: 0.0932 - val_accuracy: 0.9774 - val_top-4-accuracy: 1.0000
# Epoch 31/100
# 13/13 [==============================] - 2s 171ms/step - loss: 0.0865 - accuracy: 0.9679 - top-4-accuracy: 1.0000 - val_loss: 0.1731 - val_accuracy: 0.9605 - val_top-4-accuracy: 1.0000
# Epoch 32/100
# 13/13 [==============================] - 2s 174ms/step - loss: 0.0699 - accuracy: 0.9742 - top-4-accuracy: 1.0000 - val_loss: 0.1093 - val_accuracy: 0.9718 - val_top-4-accuracy: 1.0000
# Epoch 33/100
# 13/13 [==============================] - 2s 172ms/step - loss: 0.0644 - accuracy: 0.9723 - top-4-accuracy: 1.0000 - val_loss: 0.0876 - val_accuracy: 0.9774 - val_top-4-accuracy: 1.0000
# Epoch
uracy: 1.0000 - val_loss: 0.1067 - val_accuracy: 0.9718 - val_top-4-accuracy: 1.0000
# Epoch 69/100
# 13/13 [==============================] - 2s 168ms/step - loss: 0.0308 - accuracy: 0.9874 - top-4-accuracy: 1.0000 - val_loss: 0.0790 - val_accuracy: 0.9718 - val_top-4-accuracy: 1.0000
# Epoch 70/100
# 13/13 [==============================] - 2s 171ms/step - loss: 0.0207 - accuracy: 0.9924 - top-4-accuracy: 1.0000 - val_loss: 0.0355 - val_accuracy: 0.9887 - val_top-4-accuracy: 1.0000
# Epoch 71/100
# 13/13 [==============================] - 2s 168ms/step - loss: 0.0178 - accuracy: 0.9950 - top-4-accuracy: 1.0000 - val_loss: 0.1190 - val_accuracy: 0.9774 - val_top-4-accuracy: 1.0000
# Epoch 72/100
# 13/13 [==============================] - 2s 168ms/step - loss: 0.0567 - accuracy: 0.9830 - top-4-accuracy: 1.0000 - val_loss: 0.0786 - val_accuracy: 0.9718 - val_top-4-accuracy: 1.0000
# Epoch 73/100
# 13/13 [==============================] - 2s 169ms/step - loss: 0.0432 - accuracy: 0.9830 - top-4-accuracy: 1.0000 - val_loss: 0.1142 - val_accuracy: 0.9661 - val_top-4-accuracy: 1.0000
# Epoch 74/100
# 13/13 [==============================] - 2s 169ms/step - loss: 0.0452 - accuracy: 0.9868 - top-4-accuracy: 1.0000 - val_loss: 0.0880 - val_accuracy: 0.9774 - val_top-4-accuracy: 1.0000
# Epoch 75/100
# 13/13 [==============================] - 2s 168ms/step - loss: 0.0316 - accuracy: 0.9905 - top-4-accuracy: 1.0000 - val_loss: 0.1322 - val_accuracy: 0.9492 - val_top-4-accuracy: 1.0000
# Epoch 76/100
# 13/13 [==============================] - 2s 168ms/step - loss: 0.0478 - accuracy: 0.9868 - top-4-accuracy: 1.0000 - val_loss: 0.0843 - val_accuracy: 0.9774 - val_top-4-accuracy: 1.0000
# Epoch 77/100
# 13/13 [==============================] - 2s 169ms/step - loss: 0.0195 - accuracy: 0.9924 - top-4-accuracy: 1.0000 - val_loss: 0.0629 - val_accuracy: 0.9831 - val_top-4-accuracy: 1.0000
# Epoch 78/100
# 13/13 [==============================] - 2s 170ms/step - loss: 0.0292 - accuracy: 0.9893 - top-4-accuracy: 1.0000 - val_loss: 0.0935 - val_accuracy: 0.9661 - val_top-4-accuracy: 1.0000
# Epoch 79/100
# 13/13 [==============================] - 2s 169ms/step - loss: 0.0355 - accuracy: 0.9880 - top-4-accuracy: 1.0000 - val_loss: 0.0646 - val_accuracy: 0.9774 - val_top-4-accuracy: 1.0000
# Epoch 80/100
# 13/13 [==============================] - 2s 168ms/step - loss: 0.0442 - accuracy: 0.9868 - top-4-accuracy: 1.0000 - val_loss: 0.0633 - val_accuracy: 0.9718 - val_top-4-accuracy: 1.0000
# Epoch 81/100
# 13/13 [==============================] - 2s 170ms/step - loss: 0.0181 - accuracy: 0.9943 - top-4-accuracy: 1.0000 - val_loss: 0.0891 - val_accuracy: 0.9774 - val_top-4-accuracy: 1.0000
# Epoch 82/100
# 13/13 [==============================] - 2s 168ms/step - loss: 0.0393 - accuracy: 0.9874 - top-4-accuracy: 1.0000 - val_loss: 0.0877 - val_accuracy: 0.9661 - val_top-4-accuracy: 1.0000
# Epoch 83/100
# 13/13 [==============================] - 2s 169ms/step - loss: 0.0409 - accuracy: 0.9861 - top-4-accuracy: 1.0000 - val_loss: 0.0751 - val_accuracy: 0.9887 - val_top-4-accuracy: 1.0000
# Epoch 84/100
# 13/13 [==============================] - 2s 170ms/step - loss: 0.0240 - accuracy: 0.9918 - top-4-accuracy: 1.0000 - val_loss: 0.0782 - val_accuracy: 0.9831 - val_top-4-accuracy: 1.0000
# Epoch 85/100
# 13/13 [==============================] - 2s 171ms/step - loss: 0.0119 - accuracy: 0.9956 - top-4-accuracy: 1.0000 - val_loss: 0.0870 - val_accuracy: 0.9774 - val_top-4-accuracy: 1.0000
# Epoch 86/100
# 13/13 [==============================] - 2s 169ms/step - loss: 0.0171 - accuracy: 0.9924 - top-4-accuracy: 1.0000 - val_loss: 0.1004 - val_accuracy: 0.9774 - val_top-4-accuracy: 1.0000
# Epoch 87/100
# 13/13 [==============================] - 2s 169ms/step - loss: 0.0214 - accuracy: 0.9918 - top-4-accuracy: 1.0000 - val_loss: 0.1045 - val_accuracy: 0.9774 - val_top-4-accuracy: 1.0000
# Epoch 88/100
# 13/13 [==============================] - 2s 169ms/step - loss: 0.0228 - accuracy: 0.9899 - top-4-accuracy: 1.0000 - val_loss: 0.1302 - val_accuracy: 0.9774 - val_top-4-accuracy: 1.0000
# Epoch 89/100
# 13/13 [==============================] - 2s 168ms/step - loss: 0.0258 - accuracy: 0.9899 - top-4-accuracy: 1.0000 - val_loss: 0.0597 - val_accuracy: 0.9774 - val_top-4-accuracy: 1.0000
# Epoch 90/100
# 13/13 [==============================] - 2s 168ms/step - loss: 0.0387 - accuracy: 0.9880 - top-4-accuracy: 1.0000 - val_loss: 0.1159 - val_accuracy: 0.9661 - val_top-4-accuracy: 1.0000
# Epoch 91/100
# 13/13 [==============================] - 2s 168ms/step - loss: 0.0235 - accuracy: 0.9931 - top-4-accuracy: 1.0000 - val_loss: 0.0712 - val_accuracy: 0.9831 - val_top-4-accuracy: 1.0000
# Epoch 92/100
# 13/13 [==============================] - 2s 171ms/step - loss: 0.0155 - accuracy: 0.9937 - top-4-accuracy: 1.0000 - val_loss: 0.0818 - val_accuracy: 0.9831 - val_top-4-accuracy: 1.0000
# Epoch 93/100
# 13/13 [==============================] - 2s 168ms/step - loss: 0.0149 - accuracy: 0.9937 - top-4-accuracy: 1.0000 - val_loss: 0.0950 - val_accuracy: 0.9718 - val_top-4-accuracy: 1.0000
# Epoch 94/100
# 13/13 [==============================] - 2s 168ms/step - loss: 0.0182 - accuracy: 0.9943 - top-4-accuracy: 1.0000 - val_loss: 0.1589 - val_accuracy: 0.9718 - val_top-4-accuracy: 1.0000
# Epoch 95/100
# 13/13 [==============================] - 2s 168ms/step - loss: 0.0274 - accuracy: 0.9918 - top-4-accuracy: 1.0000 - val_loss: 0.1035 - val_accuracy: 0.9774 - val_top-4-accuracy: 1.0000
# Epoch 96/100
# 13/13 [==============================] - 2s 170ms/step - loss: 0.0160 - accuracy: 0.9937 - top-4-accuracy: 1.0000 - val_loss: 0.0999 - val_accuracy: 0.9774 - val_top-4-accuracy: 1.0000
# Epoch 97/100
# 13/13 [==============================] - 2s 169ms/step - loss: 0.0127 - accuracy: 0.9956 - top-4-accuracy: 1.0000 - val_loss: 0.1204 - val_accuracy: 0.9774 - val_top-4-accuracy: 1.0000
# Epoch 98/100
# 13/13 [==============================] - 2s 169ms/step - loss: 0.0194 - accuracy: 0.9943 - top-4-accuracy: 1.0000 - val_loss: 0.1175 - val_accuracy: 0.9831 - val_top-4-accuracy: 1.0000
# Epoch 99/100
# 13/13 [==============================] - 2s 172ms/step - loss: 0.0164 - accuracy: 0.9937 - top-4-accuracy: 1.0000 - val_loss: 0.0535 - val_accuracy: 0.9887 - val_top-4-accuracy: 1.0000
# Epoch 100/100
# 13/13 [==============================] - 2s 176ms/step - loss: 0.0298 - accuracy: 0.9905 - top-4-accuracy: 1.0000 - val_loss: 0.0623 - val_accuracy: 0.9887 - val_top-4-accuracy: 1.0000
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1439 - accuracy: 0.9760 - top-4-accuracy: 1.0000
# Test accuracy: 97.6%
# Test top 4 accuracy: 100.0%

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'top-4-accuracy', 'val_loss', 'val_accuracy', 'val_top-4-accuracy'])

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Vision Transformer Training Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc = 'upper right')
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Vision Transformer Training Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc = 'lower right')
plt.show()

# %%
y_pred = vit.predict(x_test)
y_pred=np.argmax(y_pred,axis=1)
# Out:
# 8/8 [==============================] - 1s 44ms/step

# %%
import seaborn as sns
import pandas as pd
from sklearn.metrics import classification_report
clf_report = classification_report(y_test, y_pred, target_names=["bcc","nv"], output_dict=True)
sns.heatmap(pd.DataFrame(clf_report).iloc[:-1, :].T, annot=True,  cmap="GnBu")
# Out:
# <AxesSubplot: >
