# %%
import math
import numpy as np
import cv2
import os
import random
import tensorflow as tf
from tqdm import tqdm
from tensorflow import keras
import tensorflow_addons as tfa
import matplotlib.pyplot as plt
from tensorflow.keras import layers

# Setting seed for reproducibiltiy
SEED = 42
tf.random.set_seed(SEED)

# %%
DATADIR = r"C:\Training\Training"
CATEGORIES = ["bcc","bkl","mel","nv"]
training_data = []
IMG_SIZE = 128
def create_training_data():
    for category in CATEGORIES:
        path = os.path.join(DATADIR,category)
        class_num = CATEGORIES.index(category)

        for img in tqdm(os.listdir(path)):
            try:
                img_array = cv2.imread(os.path.join(path,img))  # convert to array
                new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))  # resize to normalize data size
                training_data.append([new_array, class_num])  # add this to our training_data
            except Exception as e:  # in the interest in keeping the output clean...
                print(e)

create_training_data()

print(len(training_data))
# Out:
# 100%|██████████| 1260/1260 [00:15<00:00, 82.61it/s]
# 100%|██████████| 1260/1260 [00:07<00:00, 170.21it/s]
# 100%|██████████| 1260/1260 [00:07<00:00, 167.57it/s]
# 100%|██████████| 1260/1260 [00:09<00:00, 138.91it/s]
# 5040

# %%
random.shuffle(training_data)
X = []
y = []

for features,label in training_data:
    X.append(features)
    y.append(label)

print(X[0].reshape(-1, IMG_SIZE, IMG_SIZE, 3))

X = np.array(X).reshape(-1, IMG_SIZE, IMG_SIZE, 3)
# Out:
# [[[[137 161 184]
#    [136 164 185]
#    [135 163 184]
#    ...
#    [187 189 198]
#    [183 187 198]
#    [184 188 199]]
#
#   [[139 164 184]
#    [140 165 185]
#    [138 166 186]
#    ...
#    [188 190 199]
#    [187 189 199]
#    [187 189 200]]
#
#   [[142 165 185]
#    [139 163 183]
#    [138 163 183]
#    ...
#    [189 190 199]
#    [188 188 200]
#    [189 189 201]]
#
#   ...
#
#   [[146 167 186]
#    [149 171 188]
#    [146 171 188]
#    ...
#    [194 198 199]
#    [193 198 201]
#    [192 196 200]]
#
#   [[156 174 190]
#    [162 179 190]
#    [162 178 189]
#    ...
#    [194 198 199]
#    [194 198 199]
#    [192 197 198]]
#
#   [[149 169 186]
#    [147 169 185]
#    [158 177 191]
#    ...
#    [194 198 199]
#    [194 198 199]
#    [194 198 199]]]]

# %%
from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val = train_test_split(X, y, test_size=0.30, random_state=42)
x_val, x_test, y_val, y_test = train_test_split(x_val, y_val, test_size=0.33, random_state=42)

# %%
y_train=np.array(y_train)
y_val=np.array(y_val)
y_test=np.array(y_test)
print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_train shape: {x_val.shape} - y_train shape: {y_val.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
# Out:
# x_train shape: (3528, 128, 128, 3) - y_train shape: (3528,)
# x_train shape: (1013, 128, 128, 3) - y_train shape: (1013,)
# x_test shape: (499, 128, 128, 3) - y_test shape: (499,)

# %%
NUM_CLASSES = 4
INPUT_SHAPE = (128,128, 3)

# %%
# DATA
BUFFER_SIZE = 512
BATCH_SIZE = 128


# AUGMENTATION
IMAGE_SIZE = 72
PATCH_SIZE = 6
NUM_PATCHES = (IMAGE_SIZE // PATCH_SIZE) ** 2

# OPTIMIZER
LEARNING_RATE = 0.001
WEIGHT_DECAY = 0.0001

# TRAINING
EPOCHS = 100

# ARCHITECTURE
LAYER_NORM_EPS = 1e-6
TRANSFORMER_LAYERS = 8
PROJECTION_DIM = 64
NUM_HEADS = 4
TRANSFORMER_UNITS = [
    PROJECTION_DIM * 2,
    PROJECTION_DIM,
]
MLP_HEAD_UNITS = [2048, 1024]

# %%
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(IMAGE_SIZE, IMAGE_SIZE),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(height_factor=0.2, width_factor=0.2),
    ],
    name="data_augmentation",
)
# Compute the mean and the variance of the training data for normalization.
data_augmentation.layers[0].adapt(x_train)

# %%
class ShiftedPatchTokenization(layers.Layer):
    def __init__(
        self,
        image_size=IMAGE_SIZE,
        patch_size=PATCH_SIZE,
        num_patches=NUM_PATCHES,
        projection_dim=PROJECTION_DIM,
        vanilla=False,
        **kwargs,
    ):
        super().__init__(**kwargs)
        self.vanilla = vanilla  # Flag to swtich to vanilla patch extractor
        self.image_size = image_size
        self.patch_size = patch_size
        self.half_patch = patch_size // 2
        self.flatten_patches = layers.Reshape((num_patches, -1))
        self.projection = layers.Dense(units=projection_dim)
        self.layer_norm = layers.LayerNormalization(epsilon=LAYER_NORM_EPS)

    def crop_shift_pad(self, images, mode):
        # Build the diagonally shifted images
        if mode == "left-up":
            crop_height = self.half_patch
            crop_width = self.half_patch
            shift_height = 0
            shift_width = 0
        elif mode == "left-down":
            crop_height = 0
            crop_width = self.half_patch
            shift_height = self.half_patch
            shift_width = 0
        elif mode == "right-up":
            crop_height = self.half_patch
            crop_width = 0
            shift_height = 0
            shift_width = self.half_patch
        else:
            crop_height = 0
            crop_width = 0
            shift_height = self.half_patch
            shift_width = self.half_patch

        # Crop the shifted images and pad them
        crop = tf.image.crop_to_bounding_box(
            images,
            offset_height=crop_height,
            offset_width=crop_width,
            target_height=self.image_size - self.half_patch,
            target_width=self.image_size - self.half_patch,
        )
        shift_pad = tf.image.pad_to_bounding_box(
            crop,
            offset_height=shift_height,
            offset_width=shift_width,
            target_height=self.image_size,
            target_width=self.image_size,
        )
        return shift_pad

    def call(self, images):
        if not self.vanilla:
            # Concat the shifted images with the original image
            images = tf.concat(
                [
                    images,
                    self.crop_shift_pad(images, mode="left-up"),
                    self.crop_shift_pad(images, mode="left-down"),
                    self.crop_shift_pad(images, mode="right-up"),
                    self.crop_shift_pad(images, mode="right-down"),
                ],
                axis=-1,
            )
        # Patchify the images and flatten it
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        flat_patches = self.flatten_patches(patches)
        if not self.vanilla:
            # Layer normalize the flat patches and linearly project it
            tokens = self.layer_norm(flat_patches)
            tokens = self.projection(tokens)
        else:
            # Linearly project the flat patches
            tokens = self.projection(flat_patches)
        return (tokens, patches)

# %%
# Get a random image from the training dataset
# and resize the image
image = x_train[np.random.choice(range(x_train.shape[0]))]
resized_image = tf.image.resize(
    tf.convert_to_tensor([image]), size=(IMAGE_SIZE, IMAGE_SIZE)
)

# Vanilla patch maker: This takes an image and divides into
# patches as in the original ViT paper
(token, patch) = ShiftedPatchTokenization(vanilla=True)(resized_image / 255.0)
(token, patch) = (token[0], patch[0])
n = patch.shape[0]
count = 1
plt.figure(figsize=(4, 4))
for row in range(n):
    for col in range(n):
        plt.subplot(n, n, count)
        count = count + 1
        image = tf.reshape(patch[row][col], (PATCH_SIZE, PATCH_SIZE, 3))
        plt.imshow(image)
        plt.axis("off")
plt.show()

# Shifted Patch Tokenization: This layer takes the image, shifts it
# diagonally and then extracts patches from the concatinated images
(token, patch) = ShiftedPatchTokenization(vanilla=False)(resized_image / 255.0)
(token, patch) = (token[0], patch[0])
n = patch.shape[0]
shifted_images = ["ORIGINAL", "LEFT-UP", "LEFT-DOWN", "RIGHT-UP", "RIGHT-DOWN"]
for index, name in enumerate(shifted_images):
    print(name)
    count = 1
    plt.figure(figsize=(4, 4))
    for row in range(n):
        for col in range(n):
            plt.subplot(n, n, count)
            count = count + 1
            image = tf.reshape(patch[row][col], (PATCH_SIZE, PATCH_SIZE, 5 * 3))
            plt.imshow(image[..., 3 * index : 3 * index + 3])
            plt.axis("off")
    plt.show()
# Out:
# ORIGINAL
# LEFT-UP
# LEFT-DOWN
# RIGHT-UP
# RIGHT-DOWN

# %%
class PatchEncoder(layers.Layer):
    def __init__(
        self, num_patches=NUM_PATCHES, projection_dim=PROJECTION_DIM, **kwargs
    ):
        super().__init__(**kwargs)
        self.num_patches = num_patches
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )
        self.positions = tf.range(start=0, limit=self.num_patches, delta=1)

    def call(self, encoded_patches):
        encoded_positions = self.position_embedding(self.positions)
        encoded_patches = encoded_patches + encoded_positions
        return encoded_patches

# %%
class MultiHeadAttentionLSA(tf.keras.layers.MultiHeadAttention):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        # The trainable temperature term. The initial value is
        # the square root of the key dimension.
        self.tau = tf.Variable(math.sqrt(float(self._key_dim)), trainable=True)

    def _compute_attention(self, query, key, value, attention_mask=None, training=None):
        query = tf.multiply(query, 1.0 / self.tau)
        attention_scores = tf.einsum(self._dot_product_equation, key, query)
        attention_scores = self._masked_softmax(attention_scores, attention_mask)
        attention_scores_dropout = self._dropout_layer(
            attention_scores, training=training
        )
        attention_output = tf.einsum(
            self._combine_equation, attention_scores_dropout, value
        )
        return attention_output, attention_scores

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x


# Build the diagonal attention mask
diag_attn_mask = 1 - tf.eye(NUM_PATCHES)
diag_attn_mask = tf.cast([diag_attn_mask], dtype=tf.int8)

# %%
def create_vit_classifier(vanilla=False):
    inputs = layers.Input(shape=INPUT_SHAPE)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    (tokens, _) = ShiftedPatchTokenization(vanilla=vanilla)(augmented)
    # Encode patches.
    encoded_patches = PatchEncoder()(tokens)

    # Create multiple layers of the Transformer block.
    for _ in range(TRANSFORMER_LAYERS):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        if not vanilla:
            attention_output = MultiHeadAttentionLSA(
                num_heads=NUM_HEADS, key_dim=PROJECTION_DIM, dropout=0.1
            )(x1, x1, attention_mask=diag_attn_mask)
        else:
            attention_output = layers.MultiHeadAttention(
                num_heads=NUM_HEADS, key_dim=PROJECTION_DIM, dropout=0.1
            )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=TRANSFORMER_UNITS, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=MLP_HEAD_UNITS, dropout_rate=0.5)
    # Classify outputs.
    logits = layers.Dense(NUM_CLASSES)(features)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model

# %%
class WarmUpCosine(keras.optimizers.schedules.LearningRateSchedule):
    def __init__(
        self, learning_rate_base, total_steps, warmup_learning_rate, warmup_steps
    ):
        super().__init__()

        self.learning_rate_base = learning_rate_base
        self.total_steps = total_steps
        self.warmup_learning_rate = warmup_learning_rate
        self.warmup_steps = warmup_steps
        self.pi = tf.constant(np.pi)

    def __call__(self, step):
        if self.total_steps < self.warmup_steps:
            raise ValueError("Total_steps must be larger or equal to warmup_steps.")

        cos_annealed_lr = tf.cos(
            self.pi
            * (tf.cast(step, tf.float32) - self.warmup_steps)
            / float(self.total_steps - self.warmup_steps)
        )
        learning_rate = 0.5 * self.learning_rate_base * (1 + cos_annealed_lr)

        if self.warmup_steps > 0:
            if self.learning_rate_base < self.warmup_learning_rate:
                raise ValueError(
                    "Learning_rate_base must be larger or equal to "
                    "warmup_learning_rate."
                )
            slope = (
                self.learning_rate_base - self.warmup_learning_rate
            ) / self.warmup_steps
            warmup_rate = slope * tf.cast(step, tf.float32) + self.warmup_learning_rate
            learning_rate = tf.where(
                step < self.warmup_steps, warmup_rate, learning_rate
            )
        return tf.where(
            step > self.total_steps, 0.0, learning_rate, name="learning_rate"
        )

# %%
def run_experiment(model):
    total_steps = int((len(x_train) / BATCH_SIZE) * EPOCHS)
    warmup_epoch_percentage = 0.10
    warmup_steps = int(total_steps * warmup_epoch_percentage)
    scheduled_lrs = WarmUpCosine(
        learning_rate_base=LEARNING_RATE,
        total_steps=total_steps,
        warmup_learning_rate=0.0,
        warmup_steps=warmup_steps,
    )

    optimizer = tfa.optimizers.AdamW(
        learning_rate=LEARNING_RATE, weight_decay=WEIGHT_DECAY
    )

    model.compile(
        optimizer=optimizer,
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            keras.metrics.SparseTopKCategoricalAccuracy(4, name="top-4-accuracy"),
        ],
    )

    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=BATCH_SIZE,
        epochs=EPOCHS,
        validation_split=0.1,
    )
    _, accuracy, top_4_accuracy = model.evaluate(x_test, y_test, batch_size=BATCH_SIZE)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 4 accuracy: {round(top_4_accuracy * 100, 2)}%")

    return history


# Run experiments with the vanilla ViT
vit = create_vit_classifier(vanilla=True)
history_vanilla = run_experiment(vit)

# Run experiments with the Shifted Patch Tokenization and
# Locality Self Attention modified ViT
vit_sl = create_vit_classifier(vanilla=False)
history_sl = run_experiment(vit_sl)
# Out:
# Epoch 1/100
# 25/25 [==============================] - 14s 225ms/step - loss: 3.7497 - accuracy: 0.3748 - top-4-accuracy: 1.0000 - val_loss: 1.0937 - val_accuracy: 0.5439 - val_top-4-accuracy: 1.0000
# Epoch 2/100
# 25/25 [==============================] - 4s 167ms/step - loss: 1.3027 - accuracy: 0.4494 - top-4-accuracy: 1.0000 - val_loss: 1.0810 - val_accuracy: 0.5439 - val_top-4-accuracy: 1.0000
# Epoch 3/100
# 25/25 [==============================] - 4s 170ms/step - loss: 1.1517 - accuracy: 0.4923 - top-4-accuracy: 1.0000 - val_loss: 1.0835 - val_accuracy: 0.5751 - val_top-4-accuracy: 1.0000
# Epoch 4/100
# 25/25 [==============================] - 4s 166ms/step - loss: 1.0678 - accuracy: 0.5490 - top-4-accuracy: 1.0000 - val_loss: 0.9171 - val_accuracy: 0.6204 - val_top-4-accuracy: 1.0000
# Epoch 5/100
# 25/25 [==============================] - 4s 167ms/step - loss: 0.9993 - accuracy: 0.5707 - top-4-accuracy: 1.0000 - val_loss: 0.8667 - val_accuracy: 0.6572 - val_top-4-accuracy: 1.0000
# Epoch 6/100
# 25/25 [==============================] - 4s 168ms/step - loss: 0.9253 - accuracy: 0.6022 - top-4-accuracy: 1.0000 - val_loss: 0.8202 - val_accuracy: 0.6629 - val_top-4-accuracy: 1.0000
# Epoch 7/100
# 25/25 [==============================] - 4s 168ms/step - loss: 0.8873 - accuracy: 0.6233 - top-4-accuracy: 1.0000 - val_loss: 0.7673 - val_accuracy: 0.6629 - val_top-4-accuracy: 1.0000
# Epoch 8/100
# 25/25 [==============================] - 4s 170ms/step - loss: 0.8532 - accuracy: 0.6419 - top-4-accuracy: 1.0000 - val_loss: 0.7956 - val_accuracy: 0.6997 - val_top-4-accuracy: 1.0000
# Epoch 9/100
# 25/25 [==============================] - 4s 167ms/step - loss: 0.8523 - accuracy: 0.6302 - top-4-accuracy: 1.0000 - val_loss: 0.7548 - val_accuracy: 0.6997 - val_top-4-accuracy: 1.0000
# Epoch 10/100
# 25/25 [==============================] - 4s 170ms/step - loss: 0.8158 - accuracy: 0.6501 - top-4-accuracy: 1.0000 - val_loss: 0.7925 - val_accuracy: 0.6941 - val_top-4-accuracy: 1.0000
# Epoch 11/100
# 25/25 [==============================] - 4s 169ms/step - loss: 0.7728 - accuracy: 0.6750 - top-4-accuracy: 1.0000 - val_loss: 0.6973 - val_accuracy: 0.6969 - val_top-4-accuracy: 1.0000
# Epoch 12/100
# 25/25 [==============================] - 4s 168ms/step - loss: 0.7708 - accuracy: 0.6709 - top-4-accuracy: 1.0000 - val_loss: 0.7429 - val_accuracy: 0.7054 - val_top-4-accuracy: 1.0000
# Epoch 13/100
# 25/25 [==============================] - 4s 168ms/step - loss: 0.7132 - accuracy: 0.7008 - top-4-accuracy: 1.0000 - val_loss: 0.6790 - val_accuracy: 0.7082 - val_top-4-accuracy: 1.0000
# Epoch 14/100
# 25/25 [==============================] - 4s 168ms/step - loss: 0.7286 - accuracy: 0.6869 - top-4-accuracy: 1.0000 - val_loss: 0.7050 - val_accuracy: 0.6799 - val_top-4-accuracy: 1.0000
# Epoch 15/100
# 25/25 [==============================] - 4s 169ms/step - loss: 0.7220 - accuracy: 0.6891 - top-4-accuracy: 1.0000 - val_loss: 0.6482 - val_accuracy: 0.6969 - val_top-4-accuracy: 1.0000
# Epoch 16/100
# 25/25 [==============================] - 4s 166ms/step - loss: 0.6794 - accuracy: 0.7143 - top-4-accuracy: 1.0000 - val_loss: 0.6659 - val_accuracy: 0.7167 - val_top-4-accuracy: 1.0000
# Epoch 17/100
# 25/25 [==============================] - 4s 167ms/step - loss: 0.6691 - accuracy: 0.7228 - top-4-accuracy: 1.0000 - val_loss: 0.6476 - val_accuracy: 0.7309 - val_top-4-accuracy: 1.0000
# Epoch 18/100
# 25/25 [==============================] - 4s 171ms/step - loss: 0.6260 - accuracy: 0.7304 - top-4-accuracy: 1.0000 - val_loss: 0.6213 - val_accuracy: 0.7790 - val_top-4-accuracy: 1.0000
# Epoch 19/100
# 25/25 [==============================] - 4s 171ms/step - loss: 0.6327 - accuracy: 0.7260 - top-4-accuracy: 1.0000 - val_loss: 0.6514 - val_accuracy: 0.7450 - val_top-4-accuracy: 1.0000
# Epoch 20/100
# 25/25 [==============================] - 4s 170ms/step - loss: 0.6151 - accuracy: 0.7430 - top-4-accuracy: 1.0000 - val_loss: 0.6409 - val_accuracy: 0.7479 - val_top-4-accuracy: 1.0000
# Epoch 21/100
# 25/25 [==============================] - 4s 167ms/step - loss: 0.5801 - accuracy: 0.7587 - top-4-accuracy: 1.0000 - val_loss: 0.6172 - val_accuracy: 0.7422 - val_top-4-accuracy: 1.0000
# Epoch 22/100
# 25/25 [==============================] - 4s 166ms/step - loss: 0.5555 - accuracy: 0.7591 - top-4-accuracy: 1.0000 - val_loss: 0.6117 - val_accuracy: 0.7280 - val_top-4-accuracy: 1.0000
# Epoch 23/100
# 25/25 [==============================] - 4s 165ms/step - loss: 0.5863 - accuracy: 0.7587 - top-4-accuracy: 1.0000 - val_loss: 0.6714 - val_accuracy: 0.7337 - val_top-4-accuracy: 1.0000
# Epoch 24/100
# 25/25 [==============================] - 4s 166ms/step - loss: 0.6011 - accuracy: 0.7537 - top-4-accuracy: 1.0000 - val_loss: 0.6143 - val_accuracy: 0.7649 - val_top-4-accuracy: 1.0000
# Epoch 25/100
# 25/25 [==============================] - 4s 165ms/step - loss: 0.5705 - accuracy: 0.7638 - top-4-accuracy: 1.0000 - val_loss: 0.5992 - val_accuracy: 0.7535 - val_top-4-accuracy: 1.0000
# Epoch 26/100
# 25/25 [==============================] - 4s 167ms/step - loss: 0.5516 - accuracy: 0.7606 - top-4-accuracy: 1.0000 - val_loss: 0.6266 - val_accuracy: 0.7422 - val_top-4-accuracy: 1.0000
# Epoch 27/100
# 25/25 [==============================] - 4s 164ms/step - loss: 0.5627 - accuracy: 0.7635 - top-4-accuracy: 1.0000 - val_loss: 0.6125 - val_accuracy: 0.7592 - val_top-4-accuracy: 1.0000
# Epoch 28/100
# 25/25 [==============================] - 4s 164ms/step - loss: 0.5674 - accuracy: 0.7654 - top-4-accuracy: 1.0000 - val_loss: 0.6110 - val_accuracy: 0.7762 - val_top-4-accuracy: 1.0000
# Epoch 29/100
# 25/25 [==============================] - 4s 164ms/step - loss: 0.5124 - accuracy: 0.7874 - top-4-accuracy: 1.0000 - val_loss: 0.5865 - val_accuracy: 0.7819 - val_top-4-accuracy: 1.0000
# Epoch 30/100
# 25/25 [==============================] - 4s 166ms/step - loss: 0.5064 - accuracy: 0.7893 - top-4-accuracy: 1.0000 - val_loss: 0.6083 - val_accuracy: 0.7564 - val_top-4-accuracy: 1.0000
# Epoch 31/100
# 25/25 [==============================] - 4s 165ms/step - loss: 0.4830 - accuracy: 0.7943 - top-4-accuracy: 1.0000 - val_loss: 0.6127 - val_accuracy: 0.7507 - val_top-4-accuracy: 1.0000
# Epoch 32/100
# 25/25 [==============================] - 4s 166ms/step - loss: 0.4921 - accuracy: 0.7871 - top-4-accuracy: 1.0000 - val_loss: 0.6261 - val_accuracy: 0.7649 - val_top-4-accuracy: 1.0000
# Epoch 33/100
# 25/25 [==============================] - 4s 165ms/step - loss: 0.4836 - accuracy: 0.7909 - top-4-accuracy: 1.0000 - val_loss: 0.6020 - val_accuracy: 0.7847 - val_top-4-accuracy: 1.0000
# Epoch 34/100
# 25/25 [==============================] - 4s 167ms/step - loss: 0.4719 - accuracy: 0.8022 - top-4-accuracy: 1.0000 - val_loss: 0.6772 - val_accuracy: 0.7620 - val_top-4-accuracy: 1.0000
# Epoch 35/100
# 25/25 [==============================] - 4s 165ms/step - loss: 0.4722 - accuracy: 0.7991 - top-4-accuracy: 1.0000 - val_loss: 0.6172 - val_accuracy: 0.7734 - val_top-4-accuracy: 1.0000
# Epoch 36/100
# 25/25 [==============================] - 4s 165ms/step - loss: 0.4452 - accuracy: 0.8186 - top-4-accuracy: 1.0000 - val_loss: 0.6460 - val_accuracy: 0.7819 - val_top-4-accuracy: 1.0000
# Epoch 37/100
# 25/25 [==============================] - 4s 166ms/step - loss: 0.4275 - accuracy: 0.8236 - top-4-accuracy: 1.0000 - val_loss: 0.6887 - val_accuracy: 0.7564 - val_top-4-accuracy: 1.0000
# Epoch 38/100
# 25/25 [==============================] - 4s 167ms/step - loss: 0.4354 - accuracy: 0.8192 - top-4-accuracy: 1.0000 - val_loss: 0.6837 - val_accuracy: 0.7224 - val_top-4-accuracy: 1.0000
# Epoch 39/100
# 25/25 [==============================] - 4s 165ms/step - loss: 0.4174 - accuracy: 0.8255 - top-4-accuracy: 1.0000 - val_loss: 0.6296 - val_accuracy: 0.7535 - val_top-4-accuracy: 1.0000
# Epoch 40/100
# 25/25 [==============================] - 4s 165ms/step - loss: 0.4150 - accuracy: 0.8283 - top-4-accuracy: 1.0000 - val_loss: 0.6402 - val_accuracy: 0.7450 - val_top-4-accuracy: 1.0000
# Epoch 41/100
# 25/25 [==============================] - 4s 165ms/step - loss: 0.4210 - accuracy: 0.8227 - top-4-accuracy: 1.0000 - val_loss: 0.6364 - val_accuracy: 0.7762 - val_top-4-accuracy: 1.0000
# Epoch 42/100
# 25/25 [==============================] - 4s 165ms/step - loss: 0.4131 - accuracy: 0.8372 - top-4-accuracy: 1.0000 - val_loss: 0.5821 - val_accuracy: 0.7790 - val_top-4-accuracy: 1.0000
# Epoch 43/100
# 25/25 [==============================] - 4s 165ms/step - loss: 0.3992 - accuracy: 0.8321 - top-4-accuracy: 1.0000 - val_loss: 0.6367 - val_accuracy: 0.7337 - val_top-4-accuracy: 1.0000
# Epoch 44/100
# 25/25 [==============================] - 4s 165ms/step - loss: 0.3936 - accuracy: 0.8387 - top-4-accuracy: 1.0000 - val_loss: 0.6643 - val_accuracy: 0.7705 - val_top-4-accuracy: 1.0000
# Epoch 45/100
# 25/25 [==============================] - 4s 166ms/step - loss: 0.3775 - accuracy: 0.8425 - top-4-accuracy: 1.0000 - val_loss: 0.6905 - val_accuracy: 0.7394 - val_top-4-accuracy: 1.0000
# Epoch 46/100
# 25/25 [==============================] - 4s 165ms/step - loss: 0.3792 - accuracy: 0.8548 - top-4-accuracy: 1.0000 - val_loss: 0.7161 - val_accuracy: 0.7479 - val_top-4-accuracy: 1.0000
# Epoch 47/100
# 25/25 [==============================] - 4s 165ms/step - loss: 0.3629 - accuracy: 0.8488 - top-4-accuracy: 1.0000 - val_loss: 0.6393 - val_accuracy: 0.7819 - val_top-4-accuracy: 1.0000
# Epoch 48/100
# 25/25 [==============================] - 4s 164ms/step - loss: 0.3522 - accuracy: 0.8595 - top-4-accuracy: 1.0000 - val_loss: 0.6536 - val_accuracy: 0.7450 - val_top-4-accuracy: 1.0000
# Epoch 49/100
# 25/25 [==============================] - 4s 165ms/step - loss: 0.3558 - accuracy: 0.8586 - top-4-accuracy: 1.0000 - val_loss: 0.6501 - val_accuracy: 0.7875 - val_top-4-accuracy: 1.0000
# Epoch 50/100
# 25/25 [==============================] - 4s 165ms/step - loss: 0.3395 - accuracy: 0.8671 - top-4-accuracy: 1.0000 - val_loss: 0.7061 - val_accuracy: 0.7564 - val_top-4-accuracy: 1.0000
# Epoch 51/100
# 25/25 [==============================] - 4s 164ms/step - loss: 0.3667 - accuracy: 0.8602 - top-4-accuracy: 1.0000 - val_loss: 0.6676 - val_accuracy: 0.7620 - val_top-4-accuracy: 1.0000
# Epoch 52/100
# 25/25 [==============================] - 4s 165ms/step - loss: 0.3487 - accuracy: 0.8592 - top-4-accuracy: 1.0000 - val_loss: 0.6694 - val_accuracy: 0.7507 - val_top-4-accuracy: 1.0000
# Epoch 53/100
# 25/25 [==============================] - 4s 169ms/step - loss: 0.3238 - accuracy: 0.8683 - top-4-accuracy: 1.0000 - val_loss: 0.6944 - val_accuracy: 0.7620 - val_top-4-accuracy: 1.0000
# Epoch 54/100
# 25/25 [==============================] - 4s 167ms/step - loss: 0.3239 - accuracy: 0.8709 - top-4-accuracy: 1.0000 - val_loss: 0.7289 - val_accuracy: 0.7450 - val_top-4-accuracy: 1.0000
# Epoch 55/100
# 25/25 [==============================] - 4s 167ms/step - loss: 0.3216 - accuracy: 0.8791 - top-4-accuracy: 1.0000 - val_loss: 0.8137 - val_accuracy: 0.7705 - val_top-4-accuracy: 1.0000
# Epoch 56/100
# 25/25 [==============================] - 4s 164ms/step - loss: 0.3195 - accuracy: 0.8762 - top-4-accuracy: 1.0000 - val_loss: 0.7651 - val_accuracy: 0.7365 - val_top-4-accuracy: 1.0000
# Epoch 57/100
# 25/25 [==============================] - 4s 165ms/step - loss: 0.3031 - accuracy: 0.8769 - top-4-accuracy: 1.0000 - val_loss: 0.7520 - val_accuracy: 0.7649 - val_top-4-accuracy: 1.0000
# Epoch 58/100
# 25/25 [==============================] - 4s 168ms/step - loss: 0.3182 - accuracy: 0.8734 - top-4-accuracy: 1.0000 - val_loss: 0.7209 - val_accuracy: 0.7564 - val_top-4-accuracy: 1.0000
# Epoch 59/100
# 25/25 [==============================] - 4s 165ms/step - loss: 0.2861 - accuracy: 0.8869 - top-4-accuracy: 1.0000 - val_loss: 0.6843 - val_accuracy: 0.7535 - val_top-4-accuracy: 1.0000
# Epoch 60/100
# 25/25 [==============================] - 4s 165ms/step - loss: 0.2960 - accuracy: 0.8860 - top-4-accuracy: 1.0000 - val_loss: 0.7158 - val_accuracy: 0.7564 - val_top-4-accuracy: 1.0000
# Epoch 61/100
# 25/25 [==============================] - 4s 167ms/step - loss: 0.2927 - accuracy: 0.8894 - top-4-accuracy: 1.0000 - val_loss: 0.7895 - val_accuracy: 0.7479 - val_top-4-accuracy: 1.0000
# Epoch 62/100
# 25/25 [==============================] - 4s 164ms/step - loss: 0.2857 - accuracy: 0.8901 - top-4-accuracy: 1.0000 - val_loss: 0.7967 - val_accuracy: 0.7535 - val_top-4-accuracy: 1.0000
# Epoch 63/100
# 25/25 [==============================] - 4s 165ms/step - loss: 0.2567 - accuracy: 0.8964 - top-4-accuracy: 1.0000 - val_loss: 0.8325 - val_accuracy: 0.7365 - val_top-4-accuracy: 1.0000
# Epoch 64/100
# 25/25 [==============================] - 4s 165ms/step - loss: 0.2825 - accuracy: 0.8879 - top-4-accuracy: 1.0000 - val_loss: 0.7525 - val_accuracy: 0.7252 - val_top-4-accuracy: 1.0000
# Epoch 65/100
# 25/25 [==============================] - 4s 168ms/step - loss: 0.2501 - accuracy: 0.9011 - top-4-accuracy: 1.0000 - val_loss: 0.8160 - val_accuracy: 0.7734 - val_top-4-accuracy: 1.0000
# Epoch 66/100
# 25/25 [==============================] - 4s 164ms/step - loss: 0.2644 - accuracy: 0.8989 - top-4-accuracy: 1.0000 - val_loss: 0.8069 - val_accuracy: 0.7450 - val_top-4-accuracy: 1.0000
# Epoch 67/100
# 25/25 [==============================] - 4s 166ms/step - loss: 0.2476 - accuracy: 0.9027 - top-4-accuracy: 1.0000 - val_loss: 0.7277 - val_accuracy: 0.7762 - val_top-4-accuracy: 1.0000
# Epoch 68/100
# 25/25 [==============================] - 4s 166ms/step - loss: 0.2529 - accuracy: 0.9008 - top-4-accuracy: 1.0000 - val_loss: 0.7835 - val_accuracy: 0.7450 - val_top-4-accuracy: 1.0000
# Epoch 69/100
# 25/25 [==============================] - 4s 166ms/step - loss: 0.2848 - accuracy: 0.8926 - top-4-accuracy: 1.0000 - val_loss: 0.8259 - val_accuracy: 0.7337 - val_top-4-accuracy: 1.0000
# Epoch 70/100
# 25/25 [==============================] - 4s 164ms/step - loss: 0.2933 - accuracy: 0.8828 - top-4-accuracy: 1.0000 - val_loss: 0.7749 - val_accuracy: 0.7507 - val_top-4-accuracy: 1.0000
# Epoch 71/100
# 25/25 [==============================] - 4s 164ms/step - loss: 0.2413 - accuracy: 0.9024 - top-4-accuracy: 1.0000 - val_loss: 0.7693 - val_accuracy: 0.7705 - val_top-4-accuracy: 1.0000
# Epoch 72/100
# 25/25 [==============================] - 4s 165ms/step - loss: 0.2601 - accuracy: 0.8992 - top-4-accuracy: 1.0000 - val_loss: 0.7436 - val_accuracy: 0.7620 - val_top-4-accuracy: 1.0000
# Epoch 73/100
# 25/25 [==============================] - 4s 166ms/step - loss: 0.2567 - accuracy: 0.9068 - top-4-accuracy: 1.0000 - val_loss: 0.7921 - val_accuracy: 0.7677 - val_top-4-accuracy: 1.0000
# Epoch 74/100
# 25/25 [==============================] - 4s 165ms/step - loss: 0.2460 - accuracy: 0.9030 - top-4-accuracy: 1.0000 - val_loss: 0.8786 - val_accuracy: 0.7507 - val_top-4-accuracy: 1.0000
# Epoch 75/100
# 25/25 [==============================] - 4s 165ms/step - loss: 0.2170 - accuracy: 0.9162 - top-4-accuracy: 1.0000 - val_loss: 0.7807 - val_accuracy: 0.7762 - val_top-4-accuracy: 1.0000
# Epoch 76/100
# 25/25 [==============================] - 4s 165ms/step - loss: 0.2733 - accuracy: 0.8945 - top-4-accuracy: 1.0000 - val_loss: 0.7589 - val_accuracy: 0.7535 - val_top-4-accuracy: 1.0000
# Epoch 77/100
# 25/25 [==============================] - 4s 164ms/step - loss: 0.2182 - accuracy: 0.9191 - top-4-accuracy: 1.0000 - val_loss: 0.8262 - val_accuracy: 0.7365 - val_top-4-accuracy: 1.0000
# Epoch 78/100
# 25/25 [==============================] - 4s 164ms/step - loss: 0.1896 - accuracy: 0.9304 - top-4-accuracy: 1.0000 - val_loss: 0.8162 - val_accuracy: 0.7620 - val_top-4-accuracy: 1.0000
# Epoch 79/100
# 25/25 [==============================] - 4s 164ms/step - loss: 0.2186 - accuracy: 0.9181 - top-4-accuracy: 1.0000 - val_loss: 0.8185 - val_accuracy: 0.7620 - val_top-4-accuracy: 1.0000
# Epoch 80/100
# 25/25 [==============================] - 4s 165ms/step - loss: 0.2109 - accuracy: 0.9213 - top-4-accuracy: 1.0000 - val_loss: 0.7756 - val_accuracy: 0.7705 - val_top-4-accuracy: 1.0000
# Epoch 81/100
# 25/25 [==============================] - 4s 164ms/step - loss: 0.2068 - accuracy: 0.9231 - top-4-accuracy: 1.0000 - val_loss: 0.7842 - val_accuracy: 0.7649 - val_top-4-accuracy: 1.0000
# Epoch 82/100
# 25/25 [==============================] - 4s 164ms/step - loss: 0.2295 - accuracy: 0.9194 - top-4-accuracy: 1.0000 - val_loss: 0.7937 - val_accuracy: 0.7762 - val_top-4-accuracy: 1.0000
# Epoch 83/100
# 25/25 [==============================] - 4s 164ms/step - loss: 0.2136 - accuracy: 0.9203 - top-4-accuracy: 1.0000 - val_loss: 0.9094 - val_accuracy: 0.7592 - val_top-4-accuracy: 1.0000
# Epoch 84/100
# 25/25 [==============================] - 4s 164ms/step - loss: 0.2132 - accuracy: 0.9194 - top-4-accuracy: 1.0000 - val_loss: 0.9070 - val_accuracy: 0.7620 - val_top-4-accuracy: 1.0000
# Epoch 85/100
# 25/25 [==============================] - 4s 164ms/step - loss: 0.1738 - accuracy: 0.9294 - top-4-accuracy: 1.0000 - val_loss: 1.0096 - val_accuracy: 0.7649 - val_top-4-accuracy: 1.0000
# Epoch 86/100
# 25/25 [==============================] - 4s 164ms/step - loss: 0.1855 - accuracy: 0.9307 - top-4-accuracy: 1.0000 - val_loss: 0.8555 - val_accuracy: 0.7677 - val_top-4-accuracy: 1.0000
# Epoch 87/100
# 25/25 [==============================] - 4s 164ms/step - loss: 0.1767 - accuracy: 0.9361 - top-4-accuracy: 1.0000 - val_loss: 0.8610 - val_accuracy: 0.7904 - val_top-4-accuracy: 1.0000
# Epoch 88/100
# 25/25 [==============================] - 4s 165ms/step - loss: 0.1837 - accuracy: 0.9376 - top-4-accuracy: 1.0000 - val_loss: 0.9113 - val_accuracy: 0.7649 - val_top-4-accuracy: 1.0000
# Epoch 89/100
# 25/25 [==============================] - 4s 164ms/step - loss: 0.1636 - accuracy: 0.9427 - top-4-accuracy: 1.0000 - val_loss: 0.9740 - val_accuracy: 0.7762 - val_top-4-accuracy: 1.0000
# Epoch 90/100
# 25/25 [==============================] - 4s 164ms/step - loss: 0.1704 - accuracy: 0.9386 - top-4-accuracy: 1.0000 - val_loss: 0.9929 - val_accuracy: 0.7394 - val_top-4-accuracy: 1.0000
# Epoch 91/100
# 25/25 [==============================] - 4s 164ms/step - loss: 0.1854 - accuracy: 0.9326 - top-4-accuracy: 1.0000 - val_loss: 0.9965 - val_accuracy: 0.7734 - val_top-4-accuracy: 1.0000
# Epoch 92/100
# 25/25 [==============================] - 4s 165ms/step - loss: 0.1693 - accuracy: 0.9380 - top-4-accuracy: 1.0000 - val_loss: 0.9187 - val_accuracy: 0.7762 - val_top-4-accuracy: 1.0000
# Epoch 93/100
# 25/25 [==============================] - 4s 164ms/step - loss: 0.1967 - accuracy: 0.9238 - top-4-accuracy: 1.0000 - val_loss: 0.8973 - val_accuracy: 0.7479 - val_top-4-accuracy: 1.0000
# Epoch 94/100
# 25/25 [==============================] - 4s 164ms/step - loss: 0.1590 - accuracy: 0.9373 - top-4-accuracy: 1.0000 - val_loss: 0.9865 - val_accuracy: 0.7790 - val_top-4-accuracy: 1.0000
# Epoch 95/100
# 25/25 [==============================] - 4s 164ms/step - loss: 0.1925 - accuracy: 0.9307 - top-4-accuracy: 1.0000 - val_loss: 1.0554 - val_accuracy: 0.7280 - val_top-4-accuracy: 1.0000
# Epoch 96/100
# 25/25 [==============================] - 4s 165ms/step - loss: 0.1588 - accuracy: 0.9483 - top-4-accuracy: 1.0000 - val_loss: 0.9394 - val_accuracy: 0.7507 - val_top-4-accuracy: 1.0000
# Epoch 97/100
# 25/25 [==============================] - 4s 164ms/step - loss: 0.1353 - accuracy: 0.9461 - top-4-accuracy: 1.0000 - val_loss: 1.0426 - val_accuracy: 0.7535 - val_top-4-accuracy: 1.0000
# Epoch 98/100
# 25/25 [==============================] - 4s 168ms/step - loss: 0.1371 - accuracy: 0.9471 - top-4-accuracy: 1.0000 - val_loss: 1.1258 - val_accuracy: 0.7535 - val_top-4-accuracy: 1.0000
# Epoch 99/100
# 25/25 [==============================] - 4s 164ms/step - loss: 0.1513 - accuracy: 0.9420 - top-4-accuracy: 1.0000 - val_loss: 0.8935 - val_accuracy: 0.7705 - val_top-4-accuracy: 1.0000
# Epoch 100/100
# 25/25 [==============================] - 4s 165ms/step - loss: 0.1638 - accuracy: 0.9380 - top-4-accuracy: 1.0000 - val_loss: 1.0760 - val_accuracy: 0.7394 - val_top-4-accuracy: 1.0000
# 4/4 [==============================] - 0s 39ms/step - loss: 1.1745 - accuracy: 0.7315 - top-4-accuracy: 1.0000
# Test accuracy: 73.15%
# Test top 4 accuracy: 100.0%
# Epoch 1/100
# 25/25 [==============================] - 14s 217ms/step - loss: 2.9878 - accuracy: 0.3874 - top-4-accuracy: 1.0000 - val_loss: 1.1965 - val_accuracy: 0.4618 - val_top-4-accuracy: 1.0000
# Epoch 2/100
# 25/25 [==============================] - 4s 174ms/step - loss: 1.3396 - accuracy: 0.4633 - top-4-accuracy: 1.0000 - val_loss: 1.0968 - val_accuracy: 0.5156 - val_top-4-accuracy: 1.0000
# Epoch 3/100
# 25/25 [==============================] - 4s 175ms/step - loss: 1.1961 - accuracy: 0.4813 - top-4-accuracy: 1.0000 - val_loss: 0.9862 - val_accuracy: 0.5977 - val_top-4-accuracy: 1.0000
# Epoch 4/100
# 25/25 [==============================] - 4s 175ms/step - loss: 1.0674 - accuracy: 0.5323 - top-4-accuracy: 1.0000 - val_loss: 0.9305 - val_accuracy: 0.6034 - val_top-4-accuracy: 1.0000
# Epoch 5/100
# 25/25 [==============================] - 4s 175ms/step - loss: 1.0159 - accuracy: 0.5509 - top-4-accuracy: 1.0000 - val_loss: 0.9329 - val_accuracy: 0.5836 - val_top-4-accuracy: 1.0000
# Epoch 6/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.9668 - accuracy: 0.5628 - top-4-accuracy: 1.0000 - val_loss: 0.8494 - val_accuracy: 0.6402 - val_top-4-accuracy: 1.0000
# Epoch 7/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.9038 - accuracy: 0.6025 - top-4-accuracy: 1.0000 - val_loss: 0.8762 - val_accuracy: 0.6317 - val_top-4-accuracy: 1.0000
# Epoch 8/100
# 25/25 [==============================] - 4s 176ms/step - loss: 0.8940 - accuracy: 0.5991 - top-4-accuracy: 1.0000 - val_loss: 0.8391 - val_accuracy: 0.6629 - val_top-4-accuracy: 1.0000
# Epoch 9/100
# 25/25 [==============================] - 4s 175ms/step - loss: 0.8610 - accuracy: 0.6198 - top-4-accuracy: 1.0000 - val_loss: 0.8136 - val_accuracy: 0.6516 - val_top-4-accuracy: 1.0000
# Epoch 10/100
# 25/25 [==============================] - 4s 175ms/step - loss: 0.8546 - accuracy: 0.6217 - top-4-accuracy: 1.0000 - val_loss: 0.7512 - val_accuracy: 0.6742 - val_top-4-accuracy: 1.0000
# Epoch 11/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.8125 - accuracy: 0.6302 - top-4-accuracy: 1.0000 - val_loss: 0.7697 - val_accuracy: 0.6714 - val_top-4-accuracy: 1.0000
# Epoch 12/100
# 25/25 [==============================] - 4s 176ms/step - loss: 0.7754 - accuracy: 0.6567 - top-4-accuracy: 1.0000 - val_loss: 0.7896 - val_accuracy: 0.6742 - val_top-4-accuracy: 1.0000
# Epoch 13/100
# 25/25 [==============================] - 4s 175ms/step - loss: 0.7671 - accuracy: 0.6592 - top-4-accuracy: 1.0000 - val_loss: 0.7562 - val_accuracy: 0.6657 - val_top-4-accuracy: 1.0000
# Epoch 14/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.7543 - accuracy: 0.6728 - top-4-accuracy: 1.0000 - val_loss: 0.7273 - val_accuracy: 0.6827 - val_top-4-accuracy: 1.0000
# Epoch 15/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.7263 - accuracy: 0.6816 - top-4-accuracy: 1.0000 - val_loss: 0.7495 - val_accuracy: 0.6487 - val_top-4-accuracy: 1.0000
# Epoch 16/100
# 25/25 [==============================] - 4s 176ms/step - loss: 0.7228 - accuracy: 0.6658 - top-4-accuracy: 1.0000 - val_loss: 0.7104 - val_accuracy: 0.6771 - val_top-4-accuracy: 1.0000
# Epoch 17/100
# 25/25 [==============================] - 4s 175ms/step - loss: 0.7183 - accuracy: 0.6791 - top-4-accuracy: 1.0000 - val_loss: 0.7143 - val_accuracy: 0.6997 - val_top-4-accuracy: 1.0000
# Epoch 18/100
# 25/25 [==============================] - 4s 175ms/step - loss: 0.7036 - accuracy: 0.6800 - top-4-accuracy: 1.0000 - val_loss: 0.7016 - val_accuracy: 0.7110 - val_top-4-accuracy: 1.0000
# Epoch 19/100
# 25/25 [==============================] - 4s 175ms/step - loss: 0.7121 - accuracy: 0.6860 - top-4-accuracy: 1.0000 - val_loss: 0.7045 - val_accuracy: 0.7139 - val_top-4-accuracy: 1.0000
# Epoch 20/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.6663 - accuracy: 0.7043 - top-4-accuracy: 1.0000 - val_loss: 0.7188 - val_accuracy: 0.6884 - val_top-4-accuracy: 1.0000
# Epoch 21/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.6921 - accuracy: 0.6816 - top-4-accuracy: 1.0000 - val_loss: 0.6984 - val_accuracy: 0.7139 - val_top-4-accuracy: 1.0000
# Epoch 22/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.6581 - accuracy: 0.7191 - top-4-accuracy: 1.0000 - val_loss: 0.7060 - val_accuracy: 0.6912 - val_top-4-accuracy: 1.0000
# Epoch 23/100
# 25/25 [==============================] - 4s 177ms/step - loss: 0.6513 - accuracy: 0.7216 - top-4-accuracy: 1.0000 - val_loss: 0.7950 - val_accuracy: 0.7054 - val_top-4-accuracy: 1.0000
# Epoch 24/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.6675 - accuracy: 0.7153 - top-4-accuracy: 1.0000 - val_loss: 0.7112 - val_accuracy: 0.7195 - val_top-4-accuracy: 1.0000
# Epoch 25/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.6244 - accuracy: 0.7389 - top-4-accuracy: 1.0000 - val_loss: 0.7215 - val_accuracy: 0.7195 - val_top-4-accuracy: 1.0000
# Epoch 26/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.6156 - accuracy: 0.7294 - top-4-accuracy: 1.0000 - val_loss: 0.7034 - val_accuracy: 0.6941 - val_top-4-accuracy: 1.0000
# Epoch 27/100
# 25/25 [==============================] - 4s 175ms/step - loss: 0.6197 - accuracy: 0.7408 - top-4-accuracy: 1.0000 - val_loss: 0.6764 - val_accuracy: 0.7224 - val_top-4-accuracy: 1.0000
# Epoch 28/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.6305 - accuracy: 0.7241 - top-4-accuracy: 1.0000 - val_loss: 0.7015 - val_accuracy: 0.7365 - val_top-4-accuracy: 1.0000
# Epoch 29/100
# 25/25 [==============================] - 4s 175ms/step - loss: 0.5932 - accuracy: 0.7483 - top-4-accuracy: 1.0000 - val_loss: 0.7174 - val_accuracy: 0.7365 - val_top-4-accuracy: 1.0000
# Epoch 30/100
# 25/25 [==============================] - 4s 176ms/step - loss: 0.5969 - accuracy: 0.7449 - top-4-accuracy: 1.0000 - val_loss: 0.6862 - val_accuracy: 0.7224 - val_top-4-accuracy: 1.0000
# Epoch 31/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.5715 - accuracy: 0.7569 - top-4-accuracy: 1.0000 - val_loss: 0.6929 - val_accuracy: 0.7167 - val_top-4-accuracy: 1.0000
# Epoch 32/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.5533 - accuracy: 0.7660 - top-4-accuracy: 1.0000 - val_loss: 0.6799 - val_accuracy: 0.7280 - val_top-4-accuracy: 1.0000
# Epoch 33/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.5779 - accuracy: 0.7534 - top-4-accuracy: 1.0000 - val_loss: 0.6730 - val_accuracy: 0.7082 - val_top-4-accuracy: 1.0000
# Epoch 34/100
# 25/25 [==============================] - 4s 175ms/step - loss: 0.5520 - accuracy: 0.7701 - top-4-accuracy: 1.0000 - val_loss: 0.7287 - val_accuracy: 0.7309 - val_top-4-accuracy: 1.0000
# Epoch 35/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.5645 - accuracy: 0.7622 - top-4-accuracy: 1.0000 - val_loss: 0.7215 - val_accuracy: 0.7479 - val_top-4-accuracy: 1.0000
# Epoch 36/100
# 25/25 [==============================] - 4s 175ms/step - loss: 0.5159 - accuracy: 0.7852 - top-4-accuracy: 1.0000 - val_loss: 0.7504 - val_accuracy: 0.7167 - val_top-4-accuracy: 1.0000
# Epoch 37/100
# 25/25 [==============================] - 4s 175ms/step - loss: 0.5182 - accuracy: 0.7808 - top-4-accuracy: 1.0000 - val_loss: 0.6928 - val_accuracy: 0.7479 - val_top-4-accuracy: 1.0000
# Epoch 38/100
# 25/25 [==============================] - 4s 175ms/step - loss: 0.5186 - accuracy: 0.7798 - top-4-accuracy: 1.0000 - val_loss: 0.6934 - val_accuracy: 0.7564 - val_top-4-accuracy: 1.0000
# Epoch 39/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.5000 - accuracy: 0.7912 - top-4-accuracy: 1.0000 - val_loss: 0.7310 - val_accuracy: 0.7450 - val_top-4-accuracy: 1.0000
# Epoch 40/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.5236 - accuracy: 0.7811 - top-4-accuracy: 1.0000 - val_loss: 0.6852 - val_accuracy: 0.7620 - val_top-4-accuracy: 1.0000
# Epoch 41/100
# 25/25 [==============================] - 4s 177ms/step - loss: 0.4836 - accuracy: 0.7984 - top-4-accuracy: 1.0000 - val_loss: 0.6941 - val_accuracy: 0.7365 - val_top-4-accuracy: 1.0000
# Epoch 42/100
# 25/25 [==============================] - 4s 175ms/step - loss: 0.4842 - accuracy: 0.7981 - top-4-accuracy: 1.0000 - val_loss: 0.7051 - val_accuracy: 0.7592 - val_top-4-accuracy: 1.0000
# Epoch 43/100
# 25/25 [==============================] - 4s 175ms/step - loss: 0.4770 - accuracy: 0.7946 - top-4-accuracy: 1.0000 - val_loss: 0.7017 - val_accuracy: 0.7195 - val_top-4-accuracy: 1.0000
# Epoch 44/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.4812 - accuracy: 0.8031 - top-4-accuracy: 1.0000 - val_loss: 0.6950 - val_accuracy: 0.7195 - val_top-4-accuracy: 1.0000
# Epoch 45/100
# 25/25 [==============================] - 4s 175ms/step - loss: 0.4735 - accuracy: 0.8120 - top-4-accuracy: 1.0000 - val_loss: 0.7028 - val_accuracy: 0.7450 - val_top-4-accuracy: 1.0000
# Epoch 46/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.4531 - accuracy: 0.8135 - top-4-accuracy: 1.0000 - val_loss: 0.7550 - val_accuracy: 0.7337 - val_top-4-accuracy: 1.0000
# Epoch 47/100
# 25/25 [==============================] - 4s 173ms/step - loss: 0.4630 - accuracy: 0.8088 - top-4-accuracy: 1.0000 - val_loss: 0.6707 - val_accuracy: 0.7422 - val_top-4-accuracy: 1.0000
# Epoch 48/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.4322 - accuracy: 0.8198 - top-4-accuracy: 1.0000 - val_loss: 0.6889 - val_accuracy: 0.7422 - val_top-4-accuracy: 1.0000
# Epoch 49/100
# 25/25 [==============================] - 4s 175ms/step - loss: 0.4517 - accuracy: 0.8145 - top-4-accuracy: 1.0000 - val_loss: 0.6884 - val_accuracy: 0.7479 - val_top-4-accuracy: 1.0000
# Epoch 50/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.4355 - accuracy: 0.8246 - top-4-accuracy: 1.0000 - val_loss: 0.6937 - val_accuracy: 0.7450 - val_top-4-accuracy: 1.0000
# Epoch 51/100
# 25/25 [==============================] - 4s 173ms/step - loss: 0.4201 - accuracy: 0.8280 - top-4-accuracy: 1.0000 - val_loss: 0.6919 - val_accuracy: 0.7535 - val_top-4-accuracy: 1.0000
# Epoch 52/100
# 25/25 [==============================] - 4s 175ms/step - loss: 0.4230 - accuracy: 0.8356 - top-4-accuracy: 1.0000 - val_loss: 0.6568 - val_accuracy: 0.7394 - val_top-4-accuracy: 1.0000
# Epoch 53/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.3869 - accuracy: 0.8479 - top-4-accuracy: 1.0000 - val_loss: 0.7525 - val_accuracy: 0.7309 - val_top-4-accuracy: 1.0000
# Epoch 54/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.4322 - accuracy: 0.8287 - top-4-accuracy: 1.0000 - val_loss: 0.6895 - val_accuracy: 0.7479 - val_top-4-accuracy: 1.0000
# Epoch 55/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.4110 - accuracy: 0.8365 - top-4-accuracy: 1.0000 - val_loss: 0.6955 - val_accuracy: 0.7564 - val_top-4-accuracy: 1.0000
# Epoch 56/100
# 25/25 [==============================] - 4s 176ms/step - loss: 0.4092 - accuracy: 0.8431 - top-4-accuracy: 1.0000 - val_loss: 0.6779 - val_accuracy: 0.7649 - val_top-4-accuracy: 1.0000
# Epoch 57/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.3875 - accuracy: 0.8494 - top-4-accuracy: 1.0000 - val_loss: 0.7370 - val_accuracy: 0.6997 - val_top-4-accuracy: 1.0000
# Epoch 58/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.4169 - accuracy: 0.8425 - top-4-accuracy: 1.0000 - val_loss: 0.6907 - val_accuracy: 0.7592 - val_top-4-accuracy: 1.0000
# Epoch 59/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.3560 - accuracy: 0.8535 - top-4-accuracy: 1.0000 - val_loss: 0.6568 - val_accuracy: 0.7875 - val_top-4-accuracy: 1.0000
# Epoch 60/100
# 25/25 [==============================] - 4s 175ms/step - loss: 0.3964 - accuracy: 0.8438 - top-4-accuracy: 1.0000 - val_loss: 0.7362 - val_accuracy: 0.7507 - val_top-4-accuracy: 1.0000
# Epoch 61/100
# 25/25 [==============================] - 4s 175ms/step - loss: 0.3578 - accuracy: 0.8583 - top-4-accuracy: 1.0000 - val_loss: 0.7206 - val_accuracy: 0.7677 - val_top-4-accuracy: 1.0000
# Epoch 62/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.3514 - accuracy: 0.8658 - top-4-accuracy: 1.0000 - val_loss: 0.6859 - val_accuracy: 0.7677 - val_top-4-accuracy: 1.0000
# Epoch 63/100
# 25/25 [==============================] - 4s 176ms/step - loss: 0.3760 - accuracy: 0.8510 - top-4-accuracy: 1.0000 - val_loss: 0.7039 - val_accuracy: 0.7195 - val_top-4-accuracy: 1.0000
# Epoch 64/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.3539 - accuracy: 0.8561 - top-4-accuracy: 1.0000 - val_loss: 0.7163 - val_accuracy: 0.7620 - val_top-4-accuracy: 1.0000
# Epoch 65/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.3512 - accuracy: 0.8630 - top-4-accuracy: 1.0000 - val_loss: 0.7169 - val_accuracy: 0.7422 - val_top-4-accuracy: 1.0000
# Epoch 66/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.3069 - accuracy: 0.8772 - top-4-accuracy: 1.0000 - val_loss: 0.7407 - val_accuracy: 0.7365 - val_top-4-accuracy: 1.0000
# Epoch 67/100
# 25/25 [==============================] - 5s 181ms/step - loss: 0.3373 - accuracy: 0.8683 - top-4-accuracy: 1.0000 - val_loss: 0.7025 - val_accuracy: 0.7507 - val_top-4-accuracy: 1.0000
# Epoch 68/100
# 25/25 [==============================] - 4s 177ms/step - loss: 0.3119 - accuracy: 0.8740 - top-4-accuracy: 1.0000 - val_loss: 0.7516 - val_accuracy: 0.7450 - val_top-4-accuracy: 1.0000
# Epoch 69/100
# 25/25 [==============================] - 4s 178ms/step - loss: 0.3234 - accuracy: 0.8709 - top-4-accuracy: 1.0000 - val_loss: 0.7217 - val_accuracy: 0.7705 - val_top-4-accuracy: 1.0000
# Epoch 70/100
# 25/25 [==============================] - 4s 177ms/step - loss: 0.2833 - accuracy: 0.8869 - top-4-accuracy: 1.0000 - val_loss: 0.7762 - val_accuracy: 0.7705 - val_top-4-accuracy: 1.0000
# Epoch 71/100
# 25/25 [==============================] - 4s 175ms/step - loss: 0.3201 - accuracy: 0.8762 - top-4-accuracy: 1.0000 - val_loss: 0.7753 - val_accuracy: 0.7705 - val_top-4-accuracy: 1.0000
# Epoch 72/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.3137 - accuracy: 0.8724 - top-4-accuracy: 1.0000 - val_loss: 0.8574 - val_accuracy: 0.7450 - val_top-4-accuracy: 1.0000
# Epoch 73/100
# 25/25 [==============================] - 4s 180ms/step - loss: 0.2821 - accuracy: 0.8894 - top-4-accuracy: 1.0000 - val_loss: 0.8893 - val_accuracy: 0.7139 - val_top-4-accuracy: 1.0000
# Epoch 74/100
# 25/25 [==============================] - 4s 179ms/step - loss: 0.3024 - accuracy: 0.8866 - top-4-accuracy: 1.0000 - val_loss: 0.8021 - val_accuracy: 0.7479 - val_top-4-accuracy: 1.0000
# Epoch 75/100
# 25/25 [==============================] - 4s 175ms/step - loss: 0.2955 - accuracy: 0.8816 - top-4-accuracy: 1.0000 - val_loss: 0.7375 - val_accuracy: 0.7649 - val_top-4-accuracy: 1.0000
# Epoch 76/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.2812 - accuracy: 0.8920 - top-4-accuracy: 1.0000 - val_loss: 0.7761 - val_accuracy: 0.7677 - val_top-4-accuracy: 1.0000
# Epoch 77/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.2659 - accuracy: 0.8983 - top-4-accuracy: 1.0000 - val_loss: 0.8322 - val_accuracy: 0.7507 - val_top-4-accuracy: 1.0000
# Epoch 78/100
# 25/25 [==============================] - 4s 176ms/step - loss: 0.3156 - accuracy: 0.8791 - top-4-accuracy: 1.0000 - val_loss: 0.7571 - val_accuracy: 0.7677 - val_top-4-accuracy: 1.0000
# Epoch 79/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.2718 - accuracy: 0.8976 - top-4-accuracy: 1.0000 - val_loss: 0.7628 - val_accuracy: 0.7819 - val_top-4-accuracy: 1.0000
# Epoch 80/100
# 25/25 [==============================] - 4s 175ms/step - loss: 0.2761 - accuracy: 0.8942 - top-4-accuracy: 1.0000 - val_loss: 0.6907 - val_accuracy: 0.7875 - val_top-4-accuracy: 1.0000
# Epoch 81/100
# 25/25 [==============================] - 4s 175ms/step - loss: 0.2639 - accuracy: 0.8998 - top-4-accuracy: 1.0000 - val_loss: 0.7818 - val_accuracy: 0.7564 - val_top-4-accuracy: 1.0000
# Epoch 82/100
# 25/25 [==============================] - 4s 175ms/step - loss: 0.2593 - accuracy: 0.8970 - top-4-accuracy: 1.0000 - val_loss: 0.7728 - val_accuracy: 0.7450 - val_top-4-accuracy: 1.0000
# Epoch 83/100
# 25/25 [==============================] - 4s 175ms/step - loss: 0.2561 - accuracy: 0.8980 - top-4-accuracy: 1.0000 - val_loss: 0.8195 - val_accuracy: 0.7564 - val_top-4-accuracy: 1.0000
# Epoch 84/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.2865 - accuracy: 0.8948 - top-4-accuracy: 1.0000 - val_loss: 0.7144 - val_accuracy: 0.7762 - val_top-4-accuracy: 1.0000
# Epoch 85/100
# 25/25 [==============================] - 4s 176ms/step - loss: 0.2538 - accuracy: 0.9090 - top-4-accuracy: 1.0000 - val_loss: 0.6948 - val_accuracy: 0.7592 - val_top-4-accuracy: 1.0000
# Epoch 86/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.2292 - accuracy: 0.9153 - top-4-accuracy: 1.0000 - val_loss: 0.7431 - val_accuracy: 0.7762 - val_top-4-accuracy: 1.0000
# Epoch 87/100
# 25/25 [==============================] - 4s 178ms/step - loss: 0.2461 - accuracy: 0.9058 - top-4-accuracy: 1.0000 - val_loss: 0.7762 - val_accuracy: 0.7592 - val_top-4-accuracy: 1.0000
# Epoch 88/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.2353 - accuracy: 0.9074 - top-4-accuracy: 1.0000 - val_loss: 0.8633 - val_accuracy: 0.7762 - val_top-4-accuracy: 1.0000
# Epoch 89/100
# 25/25 [==============================] - 4s 175ms/step - loss: 0.2283 - accuracy: 0.9153 - top-4-accuracy: 1.0000 - val_loss: 0.7697 - val_accuracy: 0.7734 - val_top-4-accuracy: 1.0000
# Epoch 90/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.2459 - accuracy: 0.9055 - top-4-accuracy: 1.0000 - val_loss: 0.8029 - val_accuracy: 0.7535 - val_top-4-accuracy: 1.0000
# Epoch 91/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.2279 - accuracy: 0.9162 - top-4-accuracy: 1.0000 - val_loss: 0.8380 - val_accuracy: 0.7592 - val_top-4-accuracy: 1.0000
# Epoch 92/100
# 25/25 [==============================] - 4s 177ms/step - loss: 0.2155 - accuracy: 0.9260 - top-4-accuracy: 1.0000 - val_loss: 0.8458 - val_accuracy: 0.7677 - val_top-4-accuracy: 1.0000
# Epoch 93/100
# 25/25 [==============================] - 4s 175ms/step - loss: 0.2170 - accuracy: 0.9172 - top-4-accuracy: 1.0000 - val_loss: 0.8334 - val_accuracy: 0.7337 - val_top-4-accuracy: 1.0000
# Epoch 94/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.2174 - accuracy: 0.9165 - top-4-accuracy: 1.0000 - val_loss: 0.8546 - val_accuracy: 0.7620 - val_top-4-accuracy: 1.0000
# Epoch 95/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.2288 - accuracy: 0.9146 - top-4-accuracy: 1.0000 - val_loss: 0.8535 - val_accuracy: 0.7734 - val_top-4-accuracy: 1.0000
# Epoch 96/100
# 25/25 [==============================] - 4s 176ms/step - loss: 0.2394 - accuracy: 0.9140 - top-4-accuracy: 1.0000 - val_loss: 0.9403 - val_accuracy: 0.7649 - val_top-4-accuracy: 1.0000
# Epoch 97/100
# 25/25 [==============================] - 4s 174ms/step - loss: 0.2228 - accuracy: 0.9187 - top-4-accuracy: 1.0000 - val_loss: 0.8446 - val_accuracy: 0.7564 - val_top-4-accuracy: 1.0000
# Epoch 98/100
# 25/25 [==============================] - 4s 175ms/step - loss: 0.2142 - accuracy: 0.9276 - top-4-accuracy: 1.0000 - val_loss: 0.9700 - val_accuracy: 0.7309 - val_top-4-accuracy: 1.0000
# Epoch 99/100
# 25/25 [==============================] - 4s 175ms/step - loss: 0.2074 - accuracy: 0.9231 - top-4-accuracy: 1.0000 - val_loss: 0.8643 - val_accuracy: 0.7564 - val_top-4-accuracy: 1.0000
# Epoch 100/100
# 25/25 [==============================] - 4s 177ms/step - loss: 0.2008 - accuracy: 0.9216 - top-4-accuracy: 1.0000 - val_loss: 0.9360 - val_accuracy: 0.7620 - val_top-4-accuracy: 1.0000
# 4/4 [==============================] - 0s 44ms/step - loss: 0.8372 - accuracy: 0.7455 - top-4-accuracy: 1.0000
# Test accuracy: 74.55%
# Test top 4 accuracy: 100.0%

# %%
history_vanilla.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'top-4-accuracy', 'val_loss', 'val_accuracy', 'val_top-4-accuracy'])

# %%
history_sl.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'top-4-accuracy', 'val_loss', 'val_accuracy', 'val_top-4-accuracy'])

# %%
plt.plot(history_vanilla.history['loss'])
plt.plot(history_vanilla.history['val_loss'])
plt.title('Vanilla ViT Training Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc = 'upper right')
plt.show()

# %%
plt.plot(history_sl.history['loss'])
plt.plot(history_sl.history['val_loss'])
plt.title('Shifted Patch Tokenization and Locality Self Attention modified ViT Training Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc = 'upper right')
plt.show()

# %%
plt.plot(history_vanilla.history['accuracy'])
plt.plot(history_vanilla.history['val_accuracy'])
plt.title('Vanilla ViT Training Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc = 'lower right')
plt.show()

# %%
plt.plot(history_sl.history['accuracy'])
plt.plot(history_sl.history['val_accuracy'])
plt.title('Shifted Patch Tokenization and Locality Self Attention modified ViT Training Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc = 'lower right')
plt.show()

# %%
y_pred_vanilla = vit.predict(x_test)
y_pred_vanilla=np.argmax(y_pred_vanilla,axis=1)
# Out:
# 16/16 [==============================] - 1s 15ms/step

# %%
y_pred_sl = vit_sl.predict(x_test)
y_pred_sl=np.argmax(y_pred_sl,axis=1)
# Out:
# 16/16 [==============================] - 2s 16ms/step

# %%
import seaborn as sns
import pandas as pd
from sklearn.metrics import classification_report
clf_report = classification_report(y_test, y_pred_vanilla, target_names=["bcc","bkl","mel","nv"], output_dict=True)
sns.heatmap(pd.DataFrame(clf_report).iloc[:-1, :].T, annot=True,  cmap="GnBu")
# Out:
# <AxesSubplot: >

# %%
import seaborn as sns
import pandas as pd
from sklearn.metrics import classification_report
clf_report = classification_report(y_test, y_pred_sl, target_names=["bcc","bkl","mel","nv"], output_dict=True)
sns.heatmap(pd.DataFrame(clf_report).iloc[:-1, :].T, annot=True,  cmap="GnBu")
# Out:
# <AxesSubplot: >
